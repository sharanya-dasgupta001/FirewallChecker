# %%
# Python version of WindowsFirewallRuleParser.cs
# This assumes supporting classes like AddressSet, AddressRange, PortSet, PortRange, and NetworkProtocol are defined.

import ipaddress
import csv
from typing import List, Dict, Generator, Optional

class AddressRange:
    def __init__(self, low: str, high: str):
        self.low = ipaddress.IPv4Address(low)
        self.high = ipaddress.IPv4Address(high)

class AddressSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[AddressRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

class PortRange:
    def __init__(self, low: int, high: int):
        self.low = low
        self.high = high

class PortSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[PortRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

class NetworkProtocol:
    def __init__(self, any_protocol: bool = False, protocol_number: int = 0):
        self.any = any_protocol
        self.protocol_number = protocol_number

    @staticmethod
    def try_get_protocol_number(name: str) -> Optional[int]:
        protocol_map = {"TCP": 6, "UDP": 17, "ICMP": 1}
        return protocol_map.get(name.upper())

class WindowsFirewallRule:
    def __init__(self, name: str, remote_addresses: AddressSet, remote_ports: PortSet,
                 local_ports: PortSet, protocol: NetworkProtocol, enabled: bool, allow: bool):
        self.name = name
        self.remote_addresses = remote_addresses
        self.remote_ports = remote_ports
        self.local_ports = local_ports
        self.protocol = protocol
        self.enabled = enabled
        self.allow = allow

class WindowsFirewallRuleParser:
    REQUIRED_HEADERS = [
        "Name", "Enabled", "Action", "Local Port",
        "Remote Address", "Remote Port", "Protocol"
    ]

    @staticmethod
    def parse(text: str, separator: str) -> Generator[WindowsFirewallRule, None, None]:
        reader = csv.reader(text.strip().splitlines(), delimiter=separator)
        header_line = next(reader)
        header_index = WindowsFirewallRuleParser.parse_header(header_line)

        for i, line in enumerate(reader):
            try:
                yield WindowsFirewallRuleParser.parse_record(header_index, line)
            except Exception as e:
                print(f"Skipping line {i + 2} - {e}")

    @staticmethod
    def parse_header(header_line: List[str]) -> Dict[str, int]:
        header_index = {h.strip(): i for i, h in enumerate(header_line)}
        missing = [h for h in WindowsFirewallRuleParser.REQUIRED_HEADERS if h not in header_index]
        if missing:
            raise ValueError(f"Missing required headers: {', '.join(missing)}")
        return header_index

    @staticmethod
    def parse_record(header_index: Dict[str, int], record: List[str]) -> WindowsFirewallRule:
        def get(field: str) -> str:
            return record[header_index[field]].strip()

        return WindowsFirewallRule(
            name=get("Name"),
            remote_addresses=WindowsFirewallRuleParser.parse_address_set(get("Remote Address")),
            remote_ports=WindowsFirewallRuleParser.parse_port_set(get("Remote Port")),
            local_ports=WindowsFirewallRuleParser.parse_port_set(get("Local Port")),
            protocol=WindowsFirewallRuleParser.parse_network_protocol(get("Protocol")),
            enabled=(get("Enabled") == "Yes"),
            allow=(get("Action") == "Allow")
        )

    @staticmethod
    def parse_address_set(text: str) -> AddressSet:
        if text == "Any":
            return AddressSet(contains_all=True)

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(AddressRange(low.strip(), high.strip()))
            else:
                ranges.append(AddressRange(part, part))
        return AddressSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_port_set(text: str) -> PortSet:
        if not text:
            raise ValueError("Port is empty")

        if text == "Any":
            return PortSet(contains_all=True)

        unsupported_macros = {
            "RPC Endpoint Mapper", "RPC Dynamic Ports",
            "IPHTTPS", "Edge Traversal", "PlayTo Discovery"
        }
        if text in unsupported_macros:
            raise ValueError(f"Unsupported port macro: {text}")

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(PortRange(int(low.strip()), int(high.strip())))
            else:
                val = int(part)
                ranges.append(PortRange(val, val))
        return PortSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_network_protocol(text: str) -> NetworkProtocol:
        if text == "Any":
            return NetworkProtocol(any_protocol=True)

        protocol_number = NetworkProtocol.try_get_protocol_number(text)
        if protocol_number is None:
            protocol_number = int(text)

        return NetworkProtocol(any_protocol=False, protocol_number=protocol_number)

# Example of taking input and parsing
if __name__ == '__main__':
    import sys
    
    filename = input("Enter the firewall dump file path: ")
    # separator = input("Enter the column separator (e.g., ','): ")

    with open(filename, 'r') as f:
        text = f.read()

    print("Parsed firewall rules:")
    for rule in WindowsFirewallRuleParser.parse(text, separator='\t'):
        print(vars(rule))

# %%
# Python version of WindowsFirewallRuleParser.cs
# This assumes supporting classes like AddressSet, AddressRange, PortSet, PortRange, and NetworkProtocol are defined.

import ipaddress
import csv
from typing import List, Dict, Generator, Optional

class AddressRange:
    def __init__(self, low: str, high: str):
        self.low = ipaddress.IPv4Address(low)
        self.high = ipaddress.IPv4Address(high)

class AddressSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[AddressRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

class PortRange:
    def __init__(self, low: int, high: int):
        self.low = low
        self.high = high

class PortSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[PortRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

class NetworkProtocol:
    def __init__(self, any_protocol: bool = False, protocol_number: int = 0):
        self.any = any_protocol
        self.protocol_number = protocol_number

    @staticmethod
    def try_get_protocol_number(name: str) -> Optional[int]:
        protocol_map = {"TCP": 6, "UDP": 17, "ICMP": 1}
        return protocol_map.get(name.upper())

class WindowsFirewallRule:
    def __init__(self, name: str, remote_addresses: AddressSet, remote_ports: PortSet,
                 local_ports: PortSet, protocol: NetworkProtocol, enabled: bool, allow: bool):
        self.name = name
        self.remote_addresses = remote_addresses
        self.remote_ports = remote_ports
        self.local_ports = local_ports
        self.protocol = protocol
        self.enabled = enabled
        self.allow = allow

    def __str__(self):
        return (
            f"Rule: {self.name}\n"
            f"  Enabled: {self.enabled}, Action: {'Allow' if self.allow else 'Block'}\n"
            f"  Protocol: {'Any' if self.protocol.any else self.protocol.protocol_number}\n"
            f"  Local Ports: {'Any' if self.local_ports.contains_all else [(r.low, r.high) for r in self.local_ports.ranges]}\n"
            f"  Remote Ports: {'Any' if self.remote_ports.contains_all else [(r.low, r.high) for r in self.remote_ports.ranges]}\n"
            f"  Remote Addresses: {'Any' if self.remote_addresses.contains_all else [(str(r.low), str(r.high)) for r in self.remote_addresses.ranges]}"
        )

class WindowsFirewallRuleParser:
    REQUIRED_HEADERS = [
        "Name", "Enabled", "Action", "Local Port",
        "Remote Address", "Remote Port", "Protocol"
    ]

    @staticmethod
    def parse(text: str, separator: str) -> Generator[WindowsFirewallRule, None, None]:
        reader = csv.reader(text.strip().splitlines(), delimiter=separator)
        header_line = next(reader)
        header_index = WindowsFirewallRuleParser.parse_header(header_line)

        for i, line in enumerate(reader):
            try:
                yield WindowsFirewallRuleParser.parse_record(header_index, line)
            except Exception as e:
                print(f"Skipping line {i + 2} - {e}")

    @staticmethod
    def parse_header(header_line: List[str]) -> Dict[str, int]:
        header_index = {h.strip(): i for i, h in enumerate(header_line)}
        missing = [h for h in WindowsFirewallRuleParser.REQUIRED_HEADERS if h not in header_index]
        if missing:
            raise ValueError(f"Missing required headers: {', '.join(missing)}")
        return header_index

    @staticmethod
    def parse_record(header_index: Dict[str, int], record: List[str]) -> WindowsFirewallRule:
        def get(field: str) -> str:
            return record[header_index[field]].strip()

        return WindowsFirewallRule(
            name=get("Name"),
            remote_addresses=WindowsFirewallRuleParser.parse_address_set(get("Remote Address")),
            remote_ports=WindowsFirewallRuleParser.parse_port_set(get("Remote Port")),
            local_ports=WindowsFirewallRuleParser.parse_port_set(get("Local Port")),
            protocol=WindowsFirewallRuleParser.parse_network_protocol(get("Protocol")),
            enabled=(get("Enabled") == "Yes"),
            allow=(get("Action") == "Allow")
        )

    @staticmethod
    def parse_address_set(text: str) -> AddressSet:
        if text == "Any":
            return AddressSet(contains_all=True)

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(AddressRange(low.strip(), high.strip()))
            else:
                ranges.append(AddressRange(part, part))
        return AddressSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_port_set(text: str) -> PortSet:
        if not text:
            raise ValueError("Port is empty")

        if text == "Any":
            return PortSet(contains_all=True)

        unsupported_macros = {
            "RPC Endpoint Mapper", "RPC Dynamic Ports",
            "IPHTTPS", "Edge Traversal", "PlayTo Discovery"
        }
        if text in unsupported_macros:
            raise ValueError(f"Unsupported port macro: {text}")

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(PortRange(int(low.strip()), int(high.strip())))
            else:
                val = int(part)
                ranges.append(PortRange(val, val))
        return PortSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_network_protocol(text: str) -> NetworkProtocol:
        if text == "Any":
            return NetworkProtocol(any_protocol=True)

        protocol_number = NetworkProtocol.try_get_protocol_number(text)
        if protocol_number is None:
            protocol_number = int(text)

        return NetworkProtocol(any_protocol=False, protocol_number=protocol_number)

# Example of taking input and parsing
if __name__ == '__main__':
    import sys
    
    filename = input("Enter the firewall dump file path: ")
    # separator = input("Enter the column separator (e.g., ',', '\\t'): ")

    with open(filename, 'r') as f:
        text = f.read()

    print("Parsed firewall rules:")
    for rule in WindowsFirewallRuleParser.parse(text, separator='\t'):
        print(rule)
# Out:
# Parsed firewall rules:
# Rule: @{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.ContentDeliveryManager_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.ContentDeliveryManager/resources/AppDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.ContentDeliveryManager_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.ContentDeliveryManager/resources/AppDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.ParentalControls_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.ParentalControls/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.ParentalControls_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.ParentalControls/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.PeopleExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.PeopleExperienceHost/resources/PkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.PeopleExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.PeopleExperienceHost/resources/PkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.WindowsCalculator_10.2103.8.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsCalculator/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.WindowsCamera_2022.2201.4.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsCamera/LensSDK/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.WindowsFeedbackHub_1.2201.61.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.WindowsTerminal_1.12.10983.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsTerminal/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.XboxGameCallableUI_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.XboxGameCallableUI/resources/PkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.XboxGameCallableUI_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.XboxGameCallableUI/resources/PkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.XboxIdentityProvider_12.50.6001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxIdentityProvider/Resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftCorporationII.WindowsSubsystemForLinux_2.2.4.0_x64__8wekyb3d8bbwe?ms-resource://MicrosoftCorporationII.WindowsSubsystemForLinux/Resources/AppName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftCorporationII.WindowsSubsystemForLinux_2.2.4.0_x64__8wekyb3d8bbwe?ms-resource://MicrosoftCorporationII.WindowsSubsystemForLinux/Resources/AppName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.AIX_1000.26100.2314.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.AIX/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.Core_1000.22634.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.Core/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.Core_1000.22700.1011.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.Core/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.Client.LKG_1000.22621.3880.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.LKG/resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.LKG.AccountsService_1000.26100.3775.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.LKG.AccountsService/Resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.LKG.DesktopSpotlight_1000.26100.3775.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.LKG.DesktopSpotlight/Resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.LKG.IrisService_1000.26100.3775.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.LKG.IrisService/Resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.LKG.RulesEngine_1000.26100.3775.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.LKG.RulesEngine/Resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{MicrosoftWindows.LKG.SpeechRuntime_1000.26100.3775.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.LKG.SpeechRuntime/Resources/ProductPkgDisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{SpotifyAB.SpotifyMusic_1.261.443.0_x64__zpdnekdrzrea0?ms-resource://SpotifyAB.SpotifyMusic/Resources/AppTitle}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{WhatsNew_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://WhatsNew/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: @{WhatsNew_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://WhatsNew/resources/DisplayName}
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Spotify Music
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Spotify Music
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: AllJoyn Router (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: AllJoyn Router (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: AMD Radeon Software
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: App Installer
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Captive Portal Flow
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Rule: Cast to Device streaming server (RTP-Streaming-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Rule: ChatGPT
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Click to Do (preview)
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Connected Devices Platform - Wi-Fi Direct Transport (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Connected Devices Platform (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Connected Devices Platform (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Core Networking - DNS (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(53, 53)]
#   Remote Addresses: Any
# Rule: Core Networking - Dynamic Host Configuration Protocol (DHCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: [(68, 68)]
#   Remote Ports: [(67, 67)]
#   Remote Addresses: Any
# Rule: Core Networking - Dynamic Host Configuration Protocol for IPv6(DHCPV6-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: [(546, 546)]
#   Remote Ports: [(547, 547)]
#   Remote Addresses: Any
# Rule: Core Networking - Group Policy (LSASS-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Core Networking - Group Policy (NP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(445, 445)]
#   Remote Addresses: Any
# Rule: Core Networking - Group Policy (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 94 - invalid literal for int() with base 10: 'IGMP'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Rule: Core Networking - Teredo (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Rule: Desktop App Web Viewer
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Connected User Experiences and Telemetry
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(443, 443)]
#   Remote Addresses: Any
# Rule: Distributed Transaction Coordinator (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Rule: Dropbox promotion
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Email and accounts
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Rule: File and Printer Sharing (NB-Datagram-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(138, 138)]
#   Remote Addresses: Any
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Rule: File and Printer Sharing (NB-Name-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(137, 137)]
#   Remote Addresses: Any
# Rule: File and Printer Sharing (NB-Session-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(139, 139)]
#   Remote Addresses: Any
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Rule: File and Printer Sharing (SMB-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(445, 445)]
#   Remote Addresses: Any
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Rule: File and Printer Sharing (Restrictive) (SMB-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(445, 445)]
#   Remote Addresses: Any
# Rule: File and Printer Sharing (Restrictive) (SMB-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(445, 445)]
#   Remote Addresses: Any
# Rule: Films & TV
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Game Bar
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Get Help
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: HP Privacy Settings
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: HP Support Assistant
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: HP System Event Utility
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: iSCSI Service (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Rule: Mail and Calendar
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Rule: mDNS (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(5353, 5353)]
#   Remote Addresses: Any
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Rule: Media Center Extenders - Device Provisioning (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Media Center Extenders - Device Validation (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Rule: Microsoft 365 (Office)
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Clipchamp
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Content
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Edge
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Family Safety
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Rule: Microsoft People
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft People
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Sticky Notes
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Store
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft Tips
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Microsoft To Do
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Mixed Reality Portal
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Mixed Reality Portal
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: MSN Weather
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Narrator
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Narrator
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: NcsiUwpApp
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Rule: Network Discovery (NB-Datagram-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(138, 138)]
#   Remote Addresses: Any
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Rule: Network Discovery (NB-Name-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(137, 137)]
#   Remote Addresses: Any
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Rule: Network Discovery (UPnP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(2869, 2869)]
#   Remote Addresses: Any
# Rule: Network Discovery (WSD Events-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(5357, 5357)]
#   Remote Addresses: Any
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Rule: Network Discovery (WSD EventsSecure-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(5358, 5358)]
#   Remote Addresses: Any
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Rule: OfficePushNotificationsUtility
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: PDF Reader - View, Edit, Annotate
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Print Queue
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Proximity sharing over TCP (TCP sharing-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Recommended Troubleshooting Client (HTTP/HTTPS Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(80, 80), (443, 443)]
#   Remote Addresses: Any
# Rule: Remote Assistance (PNRP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Remote Assistance (PNRP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Remote Assistance (RA Server TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Rule: Remote Assistance (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Remote Assistance (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 224 - invalid literal for int() with base 10: 'GRE'
# Rule: Routing and Remote Access (L2TP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(1701, 1701)]
#   Remote Addresses: Any
# Rule: Routing and Remote Access (PPTP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(1723, 1723)]
#   Remote Addresses: Any
# Rule: Sign In
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Sign In
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Sign In
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Solitaire
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Start
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Store Experience Host
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: TPM Virtual Smart Card Management (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Rule: WhatsApp
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Widgets Platform Runtime
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Wi-Fi Direct Network Discovery (Out)
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Wi-Fi Direct Scan Service Use (Out)
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Wi-Fi Direct Spooler Use (Out)
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Calculator
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Camera
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Clock
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Collaboration Computer Name Registration Service (PNRP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(3540, 3540)]
#   Remote Addresses: Any
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Rule: Windows Default Lock Screen
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Defender SmartScreen
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Device Management Certificate Installer (TCP out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: [(49152, 65535)]
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Device Management Device Enroller (TCP out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: [(49152, 65535)]
#   Remote Ports: [(80, 80), (443, 443)]
#   Remote Addresses: Any
# Rule: Windows Device Management Enrollment Service (TCP out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: [(49152, 65535)]
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Device Management Sync Client (TCP out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: [(49152, 65535)]
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Feature Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Rule: Windows Management Instrumentation (WMI-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Media Player
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Peer to Peer Collaboration Foundation (PNRP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: [(3540, 3540)]
#   Remote Addresses: Any
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Rule: Windows Peer to Peer Collaboration Foundation (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Rule: Windows Print
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Security
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Shell Experience
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Sound Recorder
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Terminal
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Windows Web Experience Pack
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: windows_ie_ac_001
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: windows_ie_ac_001
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Wireless Display (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Wireless Display (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Rule: Wireless Portable Devices (TCP-Out)
#   Enabled: False, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: [(15740, 15740)]
#   Remote Addresses: Any
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'
# Rule: WFD Driver-only (TCP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 6
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: WFD Driver-only (UDP-Out)
#   Enabled: True, Action: Allow
#   Protocol: 17
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Work or school account
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Xbox Game Bar Plugin
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Xbox Game UI
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Xbox Identity Provider
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Xbox Identity Provider
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any
# Rule: Your account
#   Enabled: True, Action: Allow
#   Protocol: Any
#   Local Ports: Any
#   Remote Ports: Any
#   Remote Addresses: Any

# %%
# This code checks equivalence of two parsed firewall rule sets using Z3
from z3 import *

class FirewallEquivalenceChecker:
    def __init__(self, rules1, rules2):
        self.rules1 = rules1
        self.rules2 = rules2

    def allows(self, rules, packet):
        allowed_exprs = []
        for rule in rules:
            if not rule.enabled:
                continue

            proto_cond = BoolVal(rule.protocol.any) if rule.protocol.any else packet['protocol'] == rule.protocol.protocol_number
            local_port_cond = self.port_set_expr(packet['local_port'], rule.local_ports)
            remote_port_cond = self.port_set_expr(packet['remote_port'], rule.remote_ports)
            remote_addr_cond = self.address_set_expr(packet['remote_ip'], rule.remote_addresses)
            match_expr = And(proto_cond, local_port_cond, remote_port_cond, remote_addr_cond)

            allowed_exprs.append(And(match_expr, BoolVal(rule.allow)))

        return Or(*allowed_exprs) if allowed_exprs else BoolVal(False)

    def port_set_expr(self, port_var, port_set):
        if port_set.contains_all:
            return BoolVal(True)
        return Or([And(port_var >= r.low, port_var <= r.high) for r in port_set.ranges])

    def address_set_expr(self, ip_var, addr_set):
        if addr_set.contains_all:
            return BoolVal(True)
        return Or([
            And(ip_var >= self.ip_to_int(r.low), ip_var <= self.ip_to_int(r.high))
            for r in addr_set.ranges
        ])

    def ip_to_int(self, ip):
        return int(ip)

    def check_equivalence(self):
        # ctx = Context()
        s = Solver()

        packet = {
            'protocol': Int('proto'),
            'local_port': Int('lport'),
            'remote_port': Int('rport'),
            'remote_ip': Int('rip')
        }

        f1_allows = self.allows(self.rules1, packet)
        f2_allows = self.allows(self.rules2, packet)

        inequivalence = Not(f1_allows == f2_allows)
        s.add(inequivalence)

        if s.check() == unsat:
            print("Firewalls are equivalent.")
        else:
            print("Firewalls are NOT equivalent.")
            m = s.model()
            print("Counterexample:")
            for k, v in packet.items():
                if k == 'remote_ip':
                    print(f"  {k}: {ipaddress.IPv4Address(m[v].as_long())}")
                else :
                    print(f"  {k}: {m[v]}")


if __name__ == '__main__':
    # from windows_firewall_parser import WindowsFirewallRuleParser

    sep = '\t'#input("Enter separator (e.g., ',' or '\\t'): ")
    file1 = input("Enter first firewall file: ")
    file2 = input("Enter second firewall file: ")

    with open(file1) as f1:
        rules1 = list(WindowsFirewallRuleParser.parse(f1.read(), sep))
    with open(file2) as f2:
        rules2 = list(WindowsFirewallRuleParser.parse(f2.read(), sep))

    checker = FirewallEquivalenceChecker(rules1, rules2)
    checker.check_equivalence()
# Out:
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - invalid literal for int() with base 10: 'IGMP'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Skipping line 224 - invalid literal for int() with base 10: 'GRE'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'
# Skipping line 69 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 70 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 71 - Unsupported port macro: PlayTo Discovery
# Skipping line 72 - Expected 4 octets in 'Local subnet'
# Skipping line 74 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 76 - Expected 4 octets in 'Local subnet'
# Skipping line 77 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'Local subnet'
# Skipping line 81 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 86 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 87 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 90 - invalid literal for int() with base 10: 'IGMP'
# Skipping line 91 - Unsupported port macro: IPHTTPS
# Skipping line 92 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 93 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Expected 4 octets in 'Local subnet'
# Skipping line 96 - Expected 4 octets in 'Local subnet'
# Skipping line 97 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 98 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 99 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 100 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 101 - Unexpected '/' in 'fe80::/64'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - Unsupported port macro: Edge Traversal
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 107 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 108 - Expected 4 octets in 'Local subnet'
# Skipping line 113 - Expected 4 octets in 'Local subnet'
# Skipping line 114 - Expected 4 octets in 'Local subnet'
# Skipping line 115 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 117 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 118 - Expected 4 octets in 'Local subnet'
# Skipping line 121 - Expected 4 octets in 'Local subnet'
# Skipping line 122 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 123 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 126 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 134 - Expected 4 octets in 'Local subnet'
# Skipping line 135 - Expected 4 octets in 'Local subnet'
# Skipping line 136 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 139 - Expected 4 octets in 'Local subnet'
# Skipping line 140 - Expected 4 octets in 'Local subnet'
# Skipping line 141 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 142 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 143 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 144 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 145 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 146 - Expected 4 octets in 'Local subnet'
# Skipping line 147 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 151 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 152 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 153 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 154 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 155 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 164 - Expected 4 octets in 'Local subnet'
# Skipping line 165 - Expected 4 octets in 'Local subnet'
# Skipping line 166 - Expected 4 octets in 'Local subnet'
# Skipping line 167 - Expected 4 octets in 'Local subnet'
# Skipping line 168 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 170 - Expected 4 octets in 'Local subnet'
# Skipping line 171 - Expected 4 octets in 'Local subnet'
# Skipping line 172 - Expected 4 octets in 'Local subnet'
# Skipping line 177 - Expected 4 octets in 'Local subnet'
# Skipping line 178 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 187 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 190 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 202 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 207 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 212 - Expected 4 octets in 'Local subnet'
# Skipping line 213 - Expected 4 octets in 'Local subnet'
# Skipping line 214 - Expected 4 octets in 'Local subnet'
# Skipping line 217 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 226 - Expected 4 octets in 'Local subnet'
# Skipping line 227 - Expected 4 octets in 'Local subnet'
# Skipping line 231 - Expected 4 octets in 'Local subnet'
# Skipping line 232 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 233 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 235 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 236 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 237 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 238 - Expected 4 octets in 'Local subnet'
# Skipping line 239 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 240 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 241 - Expected 4 octets in 'Local subnet'
# Skipping line 242 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 245 - Expected 4 octets in 'Local subnet'
# Skipping line 246 - Expected 4 octets in 'Local subnet'
# Skipping line 247 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 248 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 249 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 250 - Expected 4 octets in 'Local subnet'
# Skipping line 251 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 252 - Expected 4 octets in 'Local subnet'
# Skipping line 253 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 254 - Expected 4 octets in 'Local subnet'
# Skipping line 255 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 256 - invalid literal for int() with base 10: 'GRE'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 266 - Expected 4 octets in 'Local subnet'
# Skipping line 268 - Expected 4 octets in 'Local subnet'
# Skipping line 270 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 271 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 273 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 281 - Expected 4 octets in 'Local subnet'
# Skipping line 282 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 283 - Expected 4 octets in 'Local subnet'
# Skipping line 284 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 285 - Expected 4 octets in 'Local subnet'
# Skipping line 290 - Expected 4 octets in 'Local subnet'
# Skipping line 291 - Expected 4 octets in 'Local subnet'
# Skipping line 293 - Expected 4 octets in 'Local subnet'
# Skipping line 297 - Expected 4 octets in 'Local subnet'
# Skipping line 299 - Expected 4 octets in 'Local subnet'
# Skipping line 301 - Expected 4 octets in 'Local subnet'
# Skipping line 303 - Expected 4 octets in 'Local subnet'
# Skipping line 307 - Expected 4 octets in 'Local subnet'
# Skipping line 308 - Expected 4 octets in 'Local subnet'
# Skipping line 309 - Expected 4 octets in 'Local subnet'
# Firewalls are equivalent.

# %%
#Final
# Python version of WindowsFirewallRuleParser.cs
# Assumes the existence of supporting classes like AddressSet, AddressRange, PortSet, PortRange, and NetworkProtocol.

import ipaddress
import csv
from typing import List, Dict, Generator, Optional

# Represents an IP address range from 'low' to 'high'
class AddressRange:
    def __init__(self, low: str, high: str):
        self.low = ipaddress.IPv4Address(low)
        self.high = ipaddress.IPv4Address(high)

# Represents a set of address ranges or a wildcard for all addresses
class AddressSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[AddressRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

# Represents a port range from 'low' to 'high'
class PortRange:
    def __init__(self, low: int, high: int):
        self.low = low
        self.high = high

# Represents a set of port ranges or a wildcard for all ports
class PortSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[PortRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

# Represents a network protocol (e.g., TCP, UDP, ICMP)
class NetworkProtocol:
    def __init__(self, any_protocol: bool = False, protocol_number: int = 0):
        self.any = any_protocol
        self.protocol_number = protocol_number

    @staticmethod
    def try_get_protocol_number(name: str) -> Optional[int]:
        """Map protocol name to number"""
        protocol_map = {
            "HOPOPT": 0,
            "ICMP": 1,
            "IGMP": 2,
            "TCP": 6,
            "UDP": 17,
            "IPv6": 41,
            "IPv6-Route": 43,
            "IPv6-Frag": 44,
            "GRE": 47,
            "ICMPv6": 58,
            "IPv6-NoNxt": 59,
            "IPv6-Opts": 60,
            "VRRP": 112,
            "PGM": 113,
            "L2TP": 115
        }
        return protocol_map.get(name.upper())

# Represents a single firewall rule
class WindowsFirewallRule:
    def __init__(self, name: str, remote_addresses: AddressSet, remote_ports: PortSet,
                 local_ports: PortSet, protocol: NetworkProtocol, enabled: bool, allow: bool):
        self.name = name
        self.remote_addresses = remote_addresses
        self.remote_ports = remote_ports
        self.local_ports = local_ports
        self.protocol = protocol
        self.enabled = enabled
        self.allow = allow

    def __str__(self):
        """Provides a human-readable string representation of the rule"""
        return (
            f"Rule: {self.name}\n"
            f"  Enabled: {self.enabled}, Action: {'Allow' if self.allow else 'Block'}\n"
            f"  Protocol: {'Any' if self.protocol.any else self.protocol.protocol_number}\n"
            f"  Local Ports: {'Any' if self.local_ports.contains_all else [(r.low, r.high) for r in self.local_ports.ranges]}\n"
            f"  Remote Ports: {'Any' if self.remote_ports.contains_all else [(r.low, r.high) for r in self.remote_ports.ranges]}\n"
            f"  Remote Addresses: {'Any' if self.remote_addresses.contains_all else [(str(r.low), str(r.high)) for r in self.remote_addresses.ranges]}"
        )

# Parses firewall rules from a CSV or TSV file
class WindowsFirewallRuleParser:
    REQUIRED_HEADERS = [
        "Name", "Enabled", "Action", "Local Port",
        "Remote Address", "Remote Port", "Protocol"
    ]

    @staticmethod
    def parse(text: str, separator: str) -> Generator[WindowsFirewallRule, None, None]:
        """
        Parses the given CSV/TSV text into firewall rules
        """
        reader = csv.reader(text.strip().splitlines(), delimiter=separator)
        header_line = next(reader)
        header_index = WindowsFirewallRuleParser.parse_header(header_line)

        for i, line in enumerate(reader):
            try:
                yield WindowsFirewallRuleParser.parse_record(header_index, line)
            except Exception as e:
                print(f"Skipping line {i + 2} - {e}")

    @staticmethod
    def parse_header(header_line: List[str]) -> Dict[str, int]:
        """Builds a mapping from header names to their index positions"""
        header_index = {h.strip(): i for i, h in enumerate(header_line)}
        missing = [h for h in WindowsFirewallRuleParser.REQUIRED_HEADERS if h not in header_index]
        if missing:
            raise ValueError(f"Missing required headers: {', '.join(missing)}")
        return header_index

    @staticmethod
    def parse_record(header_index: Dict[str, int], record: List[str]) -> WindowsFirewallRule:
        """Parses a single row of the firewall rules CSV into a rule object"""
        def get(field: str) -> str:
            return record[header_index[field]].strip()

        return WindowsFirewallRule(
            name=get("Name"),
            remote_addresses=WindowsFirewallRuleParser.parse_address_set(get("Remote Address")),
            remote_ports=WindowsFirewallRuleParser.parse_port_set(get("Remote Port")),
            local_ports=WindowsFirewallRuleParser.parse_port_set(get("Local Port")),
            protocol=WindowsFirewallRuleParser.parse_network_protocol(get("Protocol")),
            enabled=(get("Enabled") == "Yes"),
            allow=(get("Action") == "Allow")
        )

    @staticmethod
    def parse_address_set(text: str) -> AddressSet:
        """Parses a string representing an address set into an AddressSet object"""
        if text == "Any":
            return AddressSet(contains_all=True)

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(AddressRange(low.strip(), high.strip()))
            else:
                ranges.append(AddressRange(part, part))
        return AddressSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_port_set(text: str) -> PortSet:
        """Parses a string representing a port set into a PortSet object"""
        if not text:
            raise ValueError("Port is empty")

        if text == "Any":
            return PortSet(contains_all=True)

        unsupported_macros = {
            "RPC Endpoint Mapper", "RPC Dynamic Ports",
            "IPHTTPS", "Edge Traversal", "PlayTo Discovery"
        }
        if text in unsupported_macros:
            raise ValueError(f"Unsupported port macro: {text}")

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(PortRange(int(low.strip()), int(high.strip())))
            else:
                val = int(part)
                ranges.append(PortRange(val, val))
        return PortSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_network_protocol(text: str) -> NetworkProtocol:
        """Parses the protocol field into a NetworkProtocol object"""
        if text == "Any":
            return NetworkProtocol(any_protocol=True)

        protocol_number = NetworkProtocol.try_get_protocol_number(text)
        if protocol_number is None:
            protocol_number = int(text)

        return NetworkProtocol(any_protocol=False, protocol_number=protocol_number)

# Checks if two sets of firewall rules are logically equivalent using Z3 SMT solver
from z3 import *

class FirewallEquivalenceChecker:
    def __init__(self, rules1, rules2):
        self.rules1 = rules1
        self.rules2 = rules2

    def allows(self, rules, packet):
        """
        Encodes firewall behavior as a logical formula that determines if a packet is allowed
        """
        allowed_exprs = []
        for rule in rules:
            if not rule.enabled:
                continue

            # proto_cond = BoolVal(rule.protocol.any) if rule.protocol.any else packet['protocol'] == rule.protocol.protocol_number
            if rule.protocol.any:
                proto_cond = BoolVal(True)
            else:
                proto_cond = packet['protocol'] == rule.protocol.protocol_number
            local_port_cond = self.port_set_expr(packet['local_port'], rule.local_ports)
            remote_port_cond = self.port_set_expr(packet['remote_port'], rule.remote_ports)
            remote_addr_cond = self.address_set_expr(packet['remote_ip'], rule.remote_addresses)

            match_expr = And(proto_cond, local_port_cond, remote_port_cond, remote_addr_cond)
            allowed_exprs.append(And(match_expr, BoolVal(rule.allow)))

        return Or(*allowed_exprs) if allowed_exprs else BoolVal(False)

    def port_set_expr(self, port_var, port_set):
        """Returns a Z3 expression that matches a port against the given PortSet"""
        if port_set.contains_all:
            return BoolVal(True)
        return Or([And(port_var >= r.low, port_var <= r.high) for r in port_set.ranges])

    def address_set_expr(self, ip_var, addr_set):
        """Returns a Z3 expression that matches an IP address against the given AddressSet"""
        if addr_set.contains_all:
            return BoolVal(True)
        return Or([
            And(ip_var >= self.ip_to_int(r.low), ip_var <= self.ip_to_int(r.high))
            for r in addr_set.ranges
        ])

    def ip_to_int(self, ip):
        """Converts IPv4Address to integer for SMT encoding"""
        return int(ip)

    def check_equivalence(self):
        """Main function that checks if two rule sets are semantically equivalent"""
        s = Solver()

        # Symbolic packet representation
        packet = {
            'protocol': Int('proto'),
            'local_port': Int('lport'),
            'remote_port': Int('rport'),
            'remote_ip': Int('rip')
        }

        f1_allows = self.allows(self.rules1, packet)
        f2_allows = self.allows(self.rules2, packet)

        print(f1_allows)
        print('______________________________________________________________')
        print(f2_allows)

        # Check if there's any packet on which the rules differ
        inequivalence = Not(f1_allows == f2_allows)
        s.add(inequivalence)

        if s.check() == unsat:
            print("Firewalls are equivalent.")
        else:
            print("Firewalls are NOT equivalent.")
            print("Counterexample:")
            m = s.model()
            for k, v in packet.items():
                if k == 'remote_ip':
                    print(f"  {k}: {ipaddress.IPv4Address(m[v].as_long())}")
                else:
                    print(f"  {k}: {m[v]}")

if __name__ == '__main__':
    # Load and compare two firewall rule files
    sep = '\t'  # Assuming TSV format by default
    file1 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1.txt'#input("Enter first firewall file: ")
    file2 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1_out.txt'#input("Enter second firewall file: ")

    with open(file1) as f1:
        rules1 = list(WindowsFirewallRuleParser.parse(f1.read(), sep))
    with open(file2) as f2:
        rules2 = list(WindowsFirewallRuleParser.parse(f2.read(), sep))
# Out:
# Skipping line 69 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 70 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 71 - Unsupported port macro: PlayTo Discovery
# Skipping line 72 - Expected 4 octets in 'Local subnet'
# Skipping line 74 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 76 - Expected 4 octets in 'Local subnet'
# Skipping line 77 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'Local subnet'
# Skipping line 81 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 86 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 87 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 91 - Unsupported port macro: IPHTTPS
# Skipping line 92 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 93 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Expected 4 octets in 'Local subnet'
# Skipping line 96 - Expected 4 octets in 'Local subnet'
# Skipping line 97 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 98 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 99 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 100 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 101 - Unexpected '/' in 'fe80::/64'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - Unsupported port macro: Edge Traversal
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 107 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 108 - Expected 4 octets in 'Local subnet'
# Skipping line 113 - Expected 4 octets in 'Local subnet'
# Skipping line 114 - Expected 4 octets in 'Local subnet'
# Skipping line 115 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 117 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 118 - Expected 4 octets in 'Local subnet'
# Skipping line 121 - Expected 4 octets in 'Local subnet'
# Skipping line 122 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 123 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 126 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 134 - Expected 4 octets in 'Local subnet'
# Skipping line 135 - Expected 4 octets in 'Local subnet'
# Skipping line 136 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 139 - Expected 4 octets in 'Local subnet'
# Skipping line 140 - Expected 4 octets in 'Local subnet'
# Skipping line 141 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 142 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 143 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 144 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 145 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 146 - Expected 4 octets in 'Local subnet'
# Skipping line 147 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 151 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 152 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 153 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 154 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 155 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 164 - Expected 4 octets in 'Local subnet'
# Skipping line 165 - Expected 4 octets in 'Local subnet'
# Skipping line 166 - Expected 4 octets in 'Local subnet'
# Skipping line 167 - Expected 4 octets in 'Local subnet'
# Skipping line 168 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 170 - Expected 4 octets in 'Local subnet'
# Skipping line 171 - Expected 4 octets in 'Local subnet'
# Skipping line 172 - Expected 4 octets in 'Local subnet'
# Skipping line 177 - Expected 4 octets in 'Local subnet'
# Skipping line 178 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 187 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 190 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 202 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 207 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 212 - Expected 4 octets in 'Local subnet'
# Skipping line 213 - Expected 4 octets in 'Local subnet'
# Skipping line 214 - Expected 4 octets in 'Local subnet'
# Skipping line 217 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 226 - Expected 4 octets in 'Local subnet'
# Skipping line 227 - Expected 4 octets in 'Local subnet'
# Skipping line 231 - Expected 4 octets in 'Local subnet'
# Skipping line 232 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 233 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 235 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 236 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 237 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 238 - Expected 4 octets in 'Local subnet'
# Skipping line 239 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 240 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 241 - Expected 4 octets in 'Local subnet'
# Skipping line 242 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 245 - Expected 4 octets in 'Local subnet'
# Skipping line 246 - Expected 4 octets in 'Local subnet'
# Skipping line 247 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 248 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 249 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 250 - Expected 4 octets in 'Local subnet'
# Skipping line 251 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 252 - Expected 4 octets in 'Local subnet'
# Skipping line 253 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 254 - Expected 4 octets in 'Local subnet'
# Skipping line 255 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 266 - Expected 4 octets in 'Local subnet'
# Skipping line 268 - Expected 4 octets in 'Local subnet'
# Skipping line 270 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 271 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 273 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 281 - Expected 4 octets in 'Local subnet'
# Skipping line 282 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 283 - Expected 4 octets in 'Local subnet'
# Skipping line 284 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 285 - Expected 4 octets in 'Local subnet'
# Skipping line 290 - Expected 4 octets in 'Local subnet'
# Skipping line 291 - Expected 4 octets in 'Local subnet'
# Skipping line 293 - Expected 4 octets in 'Local subnet'
# Skipping line 297 - Expected 4 octets in 'Local subnet'
# Skipping line 299 - Expected 4 octets in 'Local subnet'
# Skipping line 301 - Expected 4 octets in 'Local subnet'
# Skipping line 303 - Expected 4 octets in 'Local subnet'
# Skipping line 307 - Expected 4 octets in 'Local subnet'
# Skipping line 308 - Expected 4 octets in 'Local subnet'
# Skipping line 309 - Expected 4 octets in 'Local subnet'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'

# %%
from z3 import *
import ipaddress

class FirewallEquivalenceChecker:
    def __init__(self, rules1, rules2, block_by_default=True):
        self.rules1 = rules1
        self.rules2 = rules2
        self.block_by_default = block_by_default

    def allows(self, rules, packet):
        """
        Encodes firewall behavior as a logical formula that determines if a packet is allowed.
        This matches the C# logic with Allow, Block, and BlockByDefault handling.
        """
        block_exprs = []
        allow_exprs = []

        for rule in rules:
            if not rule.enabled:
                continue

            # Build match expression
            proto_cond = BoolVal(True) if rule.protocol.any else packet['protocol'] == rule.protocol.protocol_number
            local_port_cond = self.port_set_expr(packet['local_port'], rule.local_ports)
            remote_port_cond = self.port_set_expr(packet['remote_port'], rule.remote_ports)
            remote_addr_cond = self.address_set_expr(packet['remote_ip'], rule.remote_addresses)

            match_expr = And(proto_cond, local_port_cond, remote_port_cond, remote_addr_cond)

            if rule.allow:
                allow_exprs.append(match_expr)
            else:
                block_exprs.append(match_expr)

        has_block = Or(*block_exprs) if block_exprs else BoolVal(False)
        has_allow = Or(*allow_exprs) if allow_exprs else BoolVal(False)

        if not self.block_by_default:
            return Not(has_block)
        else:
            return And(has_allow, Not(has_block))

    def port_set_expr(self, port_var, port_set):
        """Returns a Z3 expression that matches a port against the given PortSet."""
        if port_set.contains_all:
            return BoolVal(True)
        return Or([And(port_var >= r.low, port_var <= r.high) for r in port_set.ranges])

    def address_set_expr(self, ip_var, addr_set):
        """Returns a Z3 expression that matches an IP address against the given AddressSet."""
        if addr_set.contains_all:
            return BoolVal(True)
        return Or([
            And(ip_var >= self.ip_to_int(r.low), ip_var <= self.ip_to_int(r.high))
            for r in addr_set.ranges
        ])

    def ip_to_int(self, ip):
        """Converts IPv4Address to integer for SMT encoding."""
        return int(ip)

    def check_equivalence(self):
        """Main function that checks if two rule sets are semantically equivalent."""
        s = Solver()

        # Symbolic packet
        packet = {
            'protocol': Int('proto'),
            'local_port': Int('lport'),
            'remote_port': Int('rport'),
            'remote_ip': Int('rip')
        }

        f1_allows = self.allows(self.rules1, packet)
        f2_allows = self.allows(self.rules2, packet)

        print("Firewall 1 formula:\n", f1_allows)
        print("______________________________________________________________")
        print("Firewall 2 formula:\n", f2_allows)

        # Look for packet on which behavior differs
        s.add(f1_allows != f2_allows)

        if s.check() == unsat:
            print("✅ Firewalls are equivalent.")
        else:
            print("❌ Firewalls are NOT equivalent.")
            print("Counterexample:")
            m = s.model()
            for k, v in packet.items():
                if k == 'remote_ip':
                    print(f"  {k}: {ipaddress.IPv4Address(m[v].as_long())}")
                else:
                    print(f"  {k}: {m[v]}")
if __name__ == '__main__':
    # Load and compare two firewall rule files
    sep = '\t'  # Assuming TSV format by default
    file1 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1.txt'#input("Enter first firewall file: ")
    file2 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1_out.txt'#input("Enter second firewall file: ")

    with open(file1) as f1:
        rules1 = list(WindowsFirewallRuleParser.parse(f1.read(), sep))
    with open(file2) as f2:
        rules2 = list(WindowsFirewallRuleParser.parse(f2.read(), sep))
    checker = FirewallEquivalenceChecker(rules1, rules2)
    checker.check_equivalence()
# Out:
# Skipping line 69 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 70 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 71 - Unsupported port macro: PlayTo Discovery
# Skipping line 72 - Expected 4 octets in 'Local subnet'
# Skipping line 74 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 76 - Expected 4 octets in 'Local subnet'
# Skipping line 77 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'Local subnet'
# Skipping line 81 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 86 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 87 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 91 - Unsupported port macro: IPHTTPS
# Skipping line 92 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 93 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Expected 4 octets in 'Local subnet'
# Skipping line 96 - Expected 4 octets in 'Local subnet'
# Skipping line 97 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 98 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 99 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 100 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 101 - Unexpected '/' in 'fe80::/64'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - Unsupported port macro: Edge Traversal
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 107 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 108 - Expected 4 octets in 'Local subnet'
# Skipping line 113 - Expected 4 octets in 'Local subnet'
# Skipping line 114 - Expected 4 octets in 'Local subnet'
# Skipping line 115 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 117 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 118 - Expected 4 octets in 'Local subnet'
# Skipping line 121 - Expected 4 octets in 'Local subnet'
# Skipping line 122 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 123 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 126 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 134 - Expected 4 octets in 'Local subnet'
# Skipping line 135 - Expected 4 octets in 'Local subnet'
# Skipping line 136 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 139 - Expected 4 octets in 'Local subnet'
# Skipping line 140 - Expected 4 octets in 'Local subnet'
# Skipping line 141 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 142 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 143 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 144 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 145 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 146 - Expected 4 octets in 'Local subnet'
# Skipping line 147 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 151 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 152 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 153 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 154 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 155 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 164 - Expected 4 octets in 'Local subnet'
# Skipping line 165 - Expected 4 octets in 'Local subnet'
# Skipping line 166 - Expected 4 octets in 'Local subnet'
# Skipping line 167 - Expected 4 octets in 'Local subnet'
# Skipping line 168 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 170 - Expected 4 octets in 'Local subnet'
# Skipping line 171 - Expected 4 octets in 'Local subnet'
# Skipping line 172 - Expected 4 octets in 'Local subnet'
# Skipping line 177 - Expected 4 octets in 'Local subnet'
# Skipping line 178 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 187 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 190 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 202 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 207 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 212 - Expected 4 octets in 'Local subnet'
# Skipping line 213 - Expected 4 octets in 'Local subnet'
# Skipping line 214 - Expected 4 octets in 'Local subnet'
# Skipping line 217 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 226 - Expected 4 octets in 'Local subnet'
# Skipping line 227 - Expected 4 octets in 'Local subnet'
# Skipping line 231 - Expected 4 octets in 'Local subnet'
# Skipping line 232 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 233 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 235 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 236 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 237 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 238 - Expected 4 octets in 'Local subnet'
# Skipping line 239 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 240 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 241 - Expected 4 octets in 'Local subnet'
# Skipping line 242 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 245 - Expected 4 octets in 'Local subnet'
# Skipping line 246 - Expected 4 octets in 'Local subnet'
# Skipping line 247 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 248 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 249 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 250 - Expected 4 octets in 'Local subnet'
# Skipping line 251 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 252 - Expected 4 octets in 'Local subnet'
# Skipping line 253 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 254 - Expected 4 octets in 'Local subnet'
# Skipping line 255 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 266 - Expected 4 octets in 'Local subnet'
# Skipping line 268 - Expected 4 octets in 'Local subnet'
# Skipping line 270 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 271 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 273 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 281 - Expected 4 octets in 'Local subnet'
# Skipping line 282 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 283 - Expected 4 octets in 'Local subnet'
# Skipping line 284 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 285 - Expected 4 octets in 'Local subnet'
# Skipping line 290 - Expected 4 octets in 'Local subnet'
# Skipping line 291 - Expected 4 octets in 'Local subnet'
# Skipping line 293 - Expected 4 octets in 'Local subnet'
# Skipping line 297 - Expected 4 octets in 'Local subnet'
# Skipping line 299 - Expected 4 octets in 'Local subnet'
# Skipping line 301 - Expected 4 octets in 'Local subnet'
# Skipping line 303 - Expected 4 octets in 'Local subnet'
# Skipping line 307 - Expected 4 octets in 'Local subnet'
# Skipping line 308 - Expected 4 octets in 'Local subnet'
# Skipping line 309 - Expected 4 octets in 'Local subnet'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'

# %%
from z3 import *
import ipaddress

class FirewallEquivalenceChecker:
    def __init__(self, rules1, rules2, block_by_default=True):
        self.rules1 = rules1
        self.rules2 = rules2
        self.block_by_default = block_by_default

    def allows(self, rules, packet):
        block_exprs = []
        allow_exprs = []

        for rule in rules:
            if not rule.enabled:
                continue

            proto_cond = BoolVal(True) if rule.protocol.any else packet['protocol'] == rule.protocol.protocol_number
            local_port_cond = self.port_set_expr(packet['local_port'], rule.local_ports)
            remote_port_cond = self.port_set_expr(packet['remote_port'], rule.remote_ports)
            remote_addr_cond = self.address_set_expr(packet['remote_ip'], rule.remote_addresses)

            match_expr = And(proto_cond, local_port_cond, remote_port_cond, remote_addr_cond)

            if rule.allow:
                allow_exprs.append(match_expr)
            else:
                block_exprs.append(match_expr)

        has_block = Or(*block_exprs) if block_exprs else BoolVal(False)
        has_allow = Or(*allow_exprs) if allow_exprs else BoolVal(False)

        if not self.block_by_default:
            return Not(has_block)
        else:
            return And(has_allow, Not(has_block))

    def port_set_expr(self, port_var, port_set):
        if port_set.contains_all:
            return BoolVal(True)
        return Or([And(port_var >= r.low, port_var <= r.high) for r in port_set.ranges])

    def address_set_expr(self, ip_var, addr_set):
        if addr_set.contains_all:
            return BoolVal(True)
        return Or([
            And(ip_var >= self.ip_to_int(r.low), ip_var <= self.ip_to_int(r.high))
            for r in addr_set.ranges
        ])

    def ip_to_int(self, ip):
        return int(ip)

    def packet_from_model(self, model, packet_vars):
        """
        Extract packet values from model.
        If variable is undefined, replace with "Any".
        """
        packet_values = {}
        for k, v in packet_vars.items():
            if model[v] is not None :
                val = model.eval(v, model_completion=True)
                if k == 'remote_ip':
                    try:
                        packet_values[k] = str(ipaddress.IPv4Address(val.as_long()))
                    except Exception:
                        packet_values[k] = "Any"
                else:
                    packet_values[k] = val.as_long() if hasattr(val, 'as_long') else val
            else :
                packet_values[k] = "Any"
            # val = model.eval(v, model_completion=True)
            # if val is None:
            #     packet_values[k] = "Any"
            # else:
            #     # Special handling for remote_ip (32-bit)
            #     if k == 'remote_ip':
            #         try:
            #             packet_values[k] = str(ipaddress.IPv4Address(val.as_long()))
            #         except Exception:
            #             packet_values[k] = "Any"
            #     else:
            #         packet_values[k] = val.as_long() if hasattr(val, 'as_long') else val
        print("Packet values from model:", packet_values)
        return packet_values

    def rules_matching_packet(self, rules, packet_values):
        """
        Returns list of rule names that match the concrete packet.
        'packet_values' is a dict with concrete values (or 'Any')
        """
        matched_rules = []
        for rule in rules:
            if not rule.enabled:
                continue

            if not self.rule_matches_packet(rule, packet_values):
                continue

            matched_rules.append(rule.name if hasattr(rule, 'name') else "UnnamedRule")
        return matched_rules

    def rule_matches_packet(self, rule, packet_values):
        """
        Check if a rule matches a concrete packet (values, not symbolic)
        Supports 'Any' meaning unconstrained.
        """
        def port_in_set(port, port_set):
            if port == "Any":
                return True
            for r in port_set.ranges:
                if r.low <= port <= r.high:
                    return True
            return port_set.contains_all

        def addr_in_set(ip_str, addr_set):
            if ip_str == "Any":
                return True
            ip_int = int(ipaddress.IPv4Address(ip_str))
            for r in addr_set.ranges:
                low_int = int(r.low)
                high_int = int(r.high)
                if low_int <= ip_int <= high_int:
                    return True
            return addr_set.contains_all

        # Protocol match
        if not rule.protocol.any:
            if packet_values['protocol'] != "Any" and packet_values['protocol'] != rule.protocol.protocol_number:
                return False

        # Ports
        if not port_in_set(packet_values['local_port'], rule.local_ports):
            return False
        if not port_in_set(packet_values['remote_port'], rule.remote_ports):
            return False

        # Addresses
        if not addr_in_set(packet_values['remote_ip'], rule.remote_addresses):
            return False

        return True
    

    def check_equivalence(self, max_counterexamples=10):
        s = Solver()
        packet = {
            'protocol': Int('proto'),
            'local_port': Int('lport'),
            'remote_port': Int('rport'),
            'remote_ip': Int('rip')
        }

        f1_allows = self.allows(self.rules1, packet)
        f2_allows = self.allows(self.rules2, packet)

        s.add(f1_allows != f2_allows)

        found = 0
        while found < max_counterexamples and s.check() == sat:
            m = s.model()
            print(m)
            pkt_vals = self.packet_from_model(m, packet)

            f1_allowed = is_true(m.eval(f1_allows, model_completion=True))
            f2_allowed = is_true(m.eval(f2_allows, model_completion=True))


            f1_matching_rules = self.rules_matching_packet(self.rules1, pkt_vals)
            f2_matching_rules = self.rules_matching_packet(self.rules2, pkt_vals)

            print(f"Counterexample #{found+1}:")
            for k, v in pkt_vals.items():
                print(f"  {k}: {v}")

            print(f"  Firewall 1 allows? {f1_allowed} (Matching rules: {f1_matching_rules})")
            print(f"  Firewall 2 allows? {f2_allowed} (Matching rules: {f2_matching_rules})")
            print("-" * 50)

            # Block this solution for next iteration
            block_current = []
            for k,v in pkt_vals.items():
                if v == "Any":
                    continue  # Don't block on 'Any' values
                else :
                    block_current.append(packet[k] != v)
            print(block_current)
            s.add(Or(block_current))

            found += 1

        if found == 0:
            print("✅ Firewalls are equivalent.")

if __name__ == '__main__':
    # Load and compare two firewall rule files
    sep = '\t'  # Assuming TSV format by default
    # file1 = input("Enter first firewall file: ")
    file1 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1.txt'#
    # file2 = input("Enter second firewall file: ")
    file2 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1_out.txt'#input("Enter second firewall file: ")

    with open(file1) as f1:
        rules1 = list(WindowsFirewallRuleParser.parse(f1.read(), sep))
    with open(file2) as f2:
        rules2 = list(WindowsFirewallRuleParser.parse(f2.read(), sep))
    checker = FirewallEquivalenceChecker(rules1, rules2)
    checker.check_equivalence()
# Out:
# Skipping line 69 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 70 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 71 - Unsupported port macro: PlayTo Discovery
# Skipping line 72 - Expected 4 octets in 'Local subnet'
# Skipping line 74 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 76 - Expected 4 octets in 'Local subnet'
# Skipping line 77 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'Local subnet'
# Skipping line 81 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 86 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 87 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 91 - Unsupported port macro: IPHTTPS
# Skipping line 92 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 93 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Expected 4 octets in 'Local subnet'
# Skipping line 96 - Expected 4 octets in 'Local subnet'
# Skipping line 97 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 98 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 99 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 100 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 101 - Unexpected '/' in 'fe80::/64'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - Unsupported port macro: Edge Traversal
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 107 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 108 - Expected 4 octets in 'Local subnet'
# Skipping line 113 - Expected 4 octets in 'Local subnet'
# Skipping line 114 - Expected 4 octets in 'Local subnet'
# Skipping line 115 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 117 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 118 - Expected 4 octets in 'Local subnet'
# Skipping line 121 - Expected 4 octets in 'Local subnet'
# Skipping line 122 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 123 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 126 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 134 - Expected 4 octets in 'Local subnet'
# Skipping line 135 - Expected 4 octets in 'Local subnet'
# Skipping line 136 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 139 - Expected 4 octets in 'Local subnet'
# Skipping line 140 - Expected 4 octets in 'Local subnet'
# Skipping line 141 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 142 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 143 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 144 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 145 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 146 - Expected 4 octets in 'Local subnet'
# Skipping line 147 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 151 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 152 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 153 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 154 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 155 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 164 - Expected 4 octets in 'Local subnet'
# Skipping line 165 - Expected 4 octets in 'Local subnet'
# Skipping line 166 - Expected 4 octets in 'Local subnet'
# Skipping line 167 - Expected 4 octets in 'Local subnet'
# Skipping line 168 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 170 - Expected 4 octets in 'Local subnet'
# Skipping line 171 - Expected 4 octets in 'Local subnet'
# Skipping line 172 - Expected 4 octets in 'Local subnet'
# Skipping line 177 - Expected 4 octets in 'Local subnet'
# Skipping line 178 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 187 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 190 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 202 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 207 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 212 - Expected 4 octets in 'Local subnet'
# Skipping line 213 - Expected 4 octets in 'Local subnet'
# Skipping line 214 - Expected 4 octets in 'Local subnet'
# Skipping line 217 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 226 - Expected 4 octets in 'Local subnet'
# Skipping line 227 - Expected 4 octets in 'Local subnet'
# Skipping line 231 - Expected 4 octets in 'Local subnet'
# Skipping line 232 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 233 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 235 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 236 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 237 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 238 - Expected 4 octets in 'Local subnet'
# Skipping line 239 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 240 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 241 - Expected 4 octets in 'Local subnet'
# Skipping line 242 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 245 - Expected 4 octets in 'Local subnet'
# Skipping line 246 - Expected 4 octets in 'Local subnet'
# Skipping line 247 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 248 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 249 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 250 - Expected 4 octets in 'Local subnet'
# Skipping line 251 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 252 - Expected 4 octets in 'Local subnet'
# Skipping line 253 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 254 - Expected 4 octets in 'Local subnet'
# Skipping line 255 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 266 - Expected 4 octets in 'Local subnet'
# Skipping line 268 - Expected 4 octets in 'Local subnet'
# Skipping line 270 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 271 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 273 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 281 - Expected 4 octets in 'Local subnet'
# Skipping line 282 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 283 - Expected 4 octets in 'Local subnet'
# Skipping line 284 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 285 - Expected 4 octets in 'Local subnet'
# Skipping line 290 - Expected 4 octets in 'Local subnet'
# Skipping line 291 - Expected 4 octets in 'Local subnet'
# Skipping line 293 - Expected 4 octets in 'Local subnet'
# Skipping line 297 - Expected 4 octets in 'Local subnet'
# Skipping line 299 - Expected 4 octets in 'Local subnet'
# Skipping line 301 - Expected 4 octets in 'Local subnet'
# Skipping line 303 - Expected 4 octets in 'Local subnet'
# Skipping line 307 - Expected 4 octets in 'Local subnet'
# Skipping line 308 - Expected 4 octets in 'Local subnet'
# Skipping line 309 - Expected 4 octets in 'Local subnet'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'

# %%
checker = FirewallEquivalenceChecker(rules1, rules2)
checker.check_equivalence()
# Out:
# [proto = 17]
# Packet values from model: {'protocol': 17, 'local_port': 'Any', 'remote_port': 'Any', 'remote_ip': 'Any'}
# Counterexample #1:
#   protocol: 17
#   local_port: Any
#   remote_port: Any
#   remote_ip: Any
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [proto != 17]
# [proto = 6]
# Packet values from model: {'protocol': 6, 'local_port': 'Any', 'remote_port': 'Any', 'remote_ip': 'Any'}
# Counterexample #2:
#   protocol: 6
#   local_port: Any
#   remote_port: Any
#   remote_ip: Any
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Port 3306', 'Port 33060', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.227 ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [proto != 6]

# %%
from z3 import *
import ipaddress
from itertools import combinations

class FirewallEquivalenceChecker:
    def __init__(self, rules1, rules2, block_by_default=True):
        self.rules1 = rules1
        self.rules2 = rules2
        self.block_by_default = block_by_default

    def allows(self, rules, packet):
        block_exprs = []
        allow_exprs = []

        for rule in rules:
            if not rule.enabled:
                continue

            proto_cond = BoolVal(True) if rule.protocol.any else packet['protocol'] == rule.protocol.protocol_number
            local_port_cond = self.port_set_expr(packet['local_port'], rule.local_ports)
            remote_port_cond = self.port_set_expr(packet['remote_port'], rule.remote_ports)
            remote_addr_cond = self.address_set_expr(packet['remote_ip'], rule.remote_addresses)

            match_expr = And(proto_cond, local_port_cond, remote_port_cond, remote_addr_cond)

            if rule.allow:
                allow_exprs.append(match_expr)
            else:
                block_exprs.append(match_expr)

        has_block = Or(*block_exprs) if block_exprs else BoolVal(False)
        has_allow = Or(*allow_exprs) if allow_exprs else BoolVal(False)

        if not self.block_by_default:
            return Not(has_block)
        else:
            return And(has_allow, Not(has_block))

    def port_set_expr(self, port_var, port_set):
        if port_set.contains_all:
            return BoolVal(True)
        return Or([And(port_var >= r.low, port_var <= r.high) for r in port_set.ranges])

    def address_set_expr(self, ip_var, addr_set):
        if addr_set.contains_all:
            return BoolVal(True)
        return Or([
            And(ip_var >= self.ip_to_int(r.low), ip_var <= self.ip_to_int(r.high))
            for r in addr_set.ranges
        ])

    def ip_to_int(self, ip):
        return int(ip)

    def packet_from_model(self, model, packet_vars):
        """
        Extract packet values from model.
        If variable is undefined, replace with "Any".
        """
        packet_values = {}
        for k, v in packet_vars.items():
            val = model.eval(v, model_completion=True)
            if val is None:
                packet_values[k] = "Any"
            else:
                # Special handling for remote_ip (32-bit)
                if k == 'remote_ip':
                    try:
                        packet_values[k] = str(ipaddress.IPv4Address(val.as_long()))
                    except Exception:
                        packet_values[k] = "Any"
                else:
                    packet_values[k] = val.as_long() if hasattr(val, 'as_long') else val
        return packet_values

    def rules_matching_packet(self, rules, packet_values):
        """
        Returns list of rule names that match the concrete packet.
        'packet_values' is a dict with concrete values (or 'Any')
        """
        matched_rules = []
        for rule in rules:
            if not rule.enabled:
                continue

            if not self.rule_matches_packet(rule, packet_values):
                continue

            matched_rules.append(rule.name if hasattr(rule, 'name') else "UnnamedRule")
        return matched_rules

    def rule_matches_packet(self, rule, packet_values):
        """
        Check if a rule matches a concrete packet (values, not symbolic)
        Supports 'Any' meaning unconstrained.
        """
        def port_in_set(port, port_set):
            if port == "Any":
                return True
            for r in port_set.ranges:
                if r.low <= port <= r.high:
                    return True
            return port_set.contains_all

        def addr_in_set(ip_str, addr_set):
            if ip_str == "Any":
                return True
            ip_int = int(ipaddress.IPv4Address(ip_str))
            for r in addr_set.ranges:
                low_int = int(r.low)
                high_int = int(r.high)
                if low_int <= ip_int <= high_int:
                    return True
            return addr_set.contains_all

        # Protocol match
        if not rule.protocol.any:
            if packet_values['protocol'] != "Any" and packet_values['protocol'] != rule.protocol.protocol_number:
                return False

        # Ports
        if not port_in_set(packet_values['local_port'], rule.local_ports):
            return False
        if not port_in_set(packet_values['remote_port'], rule.remote_ports):
            return False

        # Addresses
        if not addr_in_set(packet_values['remote_ip'], rule.remote_addresses):
            return False

        return True

    def generalize_counterexample(self, model, packet_vars, f1_allows, f2_allows):
        s = Solver()
        base_constraints = []
        fixed_values = {}

        # Evaluate original concrete packet
        concrete_packet = {k: model.eval(v, model_completion=True) for k, v in packet_vars.items()}
        print("Concrete packet from model:", concrete_packet)
        print(packet_vars)

        for var_to_try_any in packet_vars:
            print(var_to_try_any)
            temp_constraints = []
            for k, v in packet_vars.items():
                if k == var_to_try_any:
                    continue
                temp_constraints.append(v == concrete_packet[k])
            print(temp_constraints)
            s.push()
            s.add(*temp_constraints)
            s.add(f1_allows != f2_allows)
            if s.check() != sat:
                print("yes")
                s.pop()
            else:
                s.pop()
                fixed_values[var_to_try_any] = concrete_packet[var_to_try_any]
                print(concrete_packet[var_to_try_any])

        return fixed_values

    def check_equivalence(self, max_counterexamples=10):
        s = Solver()
        packet = {
            'protocol': Int('proto'),
            'local_port': Int('lport'),
            'remote_port': Int('rport'),
            'remote_ip': Int('rip')
        }

        f1_allows = self.allows(self.rules1, packet)
        f2_allows = self.allows(self.rules2, packet)

        s.add(f1_allows != f2_allows)

        seen_patterns = set()
        found = 0

        while found < max_counterexamples and s.check() == sat:
            m = s.model()
            print(m)
            fixed_vars = self.generalize_counterexample(m, packet, f1_allows, f2_allows)
            print(fixed_vars)

            key = tuple((k, fixed_vars[k].as_long()) for k in sorted(fixed_vars))
            if key in seen_patterns:
                break  # Already seen
            seen_patterns.add(key)

            pkt_repr = {}
            for k in packet:
                if k in fixed_vars:
                    if k == 'remote_ip':
                        pkt_repr[k] = str(ipaddress.IPv4Address(fixed_vars[k].as_long()))
                    else:
                        pkt_repr[k] = fixed_vars[k].as_long()
                else:
                    pkt_repr[k] = "Any"

            f1_allowed = is_true(m.eval(f1_allows, model_completion=True))
            f2_allowed = is_true(m.eval(f2_allows, model_completion=True))

            f1_matching = self.rules_matching_packet(self.rules1, pkt_repr)
            f2_matching = self.rules_matching_packet(self.rules2, pkt_repr)

            print(f"Generalized Counterexample #{found + 1}:")
            for k in ['protocol', 'local_port', 'remote_port', 'remote_ip']:
                print(f"  {k}: {pkt_repr[k]}")
            print(f"  Firewall 1 allows? {f1_allowed} (Matching rules: {f1_matching})")
            print(f"  Firewall 2 allows? {f2_allowed} (Matching rules: {f2_matching})")
            print("-" * 50)

            # Block future packets with same fixed assignments
            block_clause = [packet[k] == v for k, v in fixed_vars.items()]
            s.add(Not(And(block_clause)))

            found += 1

        if found == 0:
            print("✅ Firewalls are equivalent.")



if __name__ == '__main__':
    # Load and compare two firewall rule files
    sep = '\t'  # Assuming TSV format by default
    file1 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1.txt'#input("Enter first firewall file: ")
    file2 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1_out.txt'#input("Enter second firewall file: ")

    with open(file1) as f1:
        rules1 = list(WindowsFirewallRuleParser.parse(f1.read(), sep))
    with open(file2) as f2:
        rules2 = list(WindowsFirewallRuleParser.parse(f2.read(), sep))
# Out:
# Skipping line 69 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 70 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 71 - Unsupported port macro: PlayTo Discovery
# Skipping line 72 - Expected 4 octets in 'Local subnet'
# Skipping line 74 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 76 - Expected 4 octets in 'Local subnet'
# Skipping line 77 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'Local subnet'
# Skipping line 81 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 86 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 87 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 91 - Unsupported port macro: IPHTTPS
# Skipping line 92 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 93 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Expected 4 octets in 'Local subnet'
# Skipping line 96 - Expected 4 octets in 'Local subnet'
# Skipping line 97 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 98 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 99 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 100 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 101 - Unexpected '/' in 'fe80::/64'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - Unsupported port macro: Edge Traversal
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 107 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 108 - Expected 4 octets in 'Local subnet'
# Skipping line 113 - Expected 4 octets in 'Local subnet'
# Skipping line 114 - Expected 4 octets in 'Local subnet'
# Skipping line 115 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 117 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 118 - Expected 4 octets in 'Local subnet'
# Skipping line 121 - Expected 4 octets in 'Local subnet'
# Skipping line 122 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 123 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 126 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 134 - Expected 4 octets in 'Local subnet'
# Skipping line 135 - Expected 4 octets in 'Local subnet'
# Skipping line 136 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 139 - Expected 4 octets in 'Local subnet'
# Skipping line 140 - Expected 4 octets in 'Local subnet'
# Skipping line 141 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 142 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 143 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 144 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 145 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 146 - Expected 4 octets in 'Local subnet'
# Skipping line 147 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 151 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 152 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 153 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 154 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 155 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 164 - Expected 4 octets in 'Local subnet'
# Skipping line 165 - Expected 4 octets in 'Local subnet'
# Skipping line 166 - Expected 4 octets in 'Local subnet'
# Skipping line 167 - Expected 4 octets in 'Local subnet'
# Skipping line 168 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 170 - Expected 4 octets in 'Local subnet'
# Skipping line 171 - Expected 4 octets in 'Local subnet'
# Skipping line 172 - Expected 4 octets in 'Local subnet'
# Skipping line 177 - Expected 4 octets in 'Local subnet'
# Skipping line 178 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 187 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 190 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 202 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 207 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 212 - Expected 4 octets in 'Local subnet'
# Skipping line 213 - Expected 4 octets in 'Local subnet'
# Skipping line 214 - Expected 4 octets in 'Local subnet'
# Skipping line 217 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 226 - Expected 4 octets in 'Local subnet'
# Skipping line 227 - Expected 4 octets in 'Local subnet'
# Skipping line 231 - Expected 4 octets in 'Local subnet'
# Skipping line 232 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 233 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 235 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 236 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 237 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 238 - Expected 4 octets in 'Local subnet'
# Skipping line 239 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 240 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 241 - Expected 4 octets in 'Local subnet'
# Skipping line 242 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 245 - Expected 4 octets in 'Local subnet'
# Skipping line 246 - Expected 4 octets in 'Local subnet'
# Skipping line 247 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 248 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 249 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 250 - Expected 4 octets in 'Local subnet'
# Skipping line 251 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 252 - Expected 4 octets in 'Local subnet'
# Skipping line 253 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 254 - Expected 4 octets in 'Local subnet'
# Skipping line 255 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 266 - Expected 4 octets in 'Local subnet'
# Skipping line 268 - Expected 4 octets in 'Local subnet'
# Skipping line 270 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 271 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 273 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 281 - Expected 4 octets in 'Local subnet'
# Skipping line 282 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 283 - Expected 4 octets in 'Local subnet'
# Skipping line 284 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 285 - Expected 4 octets in 'Local subnet'
# Skipping line 290 - Expected 4 octets in 'Local subnet'
# Skipping line 291 - Expected 4 octets in 'Local subnet'
# Skipping line 293 - Expected 4 octets in 'Local subnet'
# Skipping line 297 - Expected 4 octets in 'Local subnet'
# Skipping line 299 - Expected 4 octets in 'Local subnet'
# Skipping line 301 - Expected 4 octets in 'Local subnet'
# Skipping line 303 - Expected 4 octets in 'Local subnet'
# Skipping line 307 - Expected 4 octets in 'Local subnet'
# Skipping line 308 - Expected 4 octets in 'Local subnet'
# Skipping line 309 - Expected 4 octets in 'Local subnet'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'

# %%
checker = FirewallEquivalenceChecker(rules1, rules2)
checker.check_equivalence()
# Out:
# [proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 0}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [0 == lport, 0 == rport, 0 == rip]
# 6
# local_port
# [6 == proto, 0 == rport, 0 == rip]
# 0
# remote_port
# [6 == proto, 0 == lport, 0 == rip]
# 0
# remote_ip
# [6 == proto, 0 == lport, 0 == rport]
# 0
# {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 0}
# Generalized Counterexample #1:
#   protocol: 6
#   local_port: 0
#   remote_port: 0
#   remote_ip: 0.0.0.0
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [rip = 2, proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 2}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [0 == lport, 0 == rport, 2 == rip]
# 6
# local_port
# [6 == proto, 0 == rport, 2 == rip]
# 0
# remote_port
# [6 == proto, 0 == lport, 2 == rip]
# 0
# remote_ip
# [6 == proto, 0 == lport, 0 == rport]
# 2
# {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 2}
# Generalized Counterexample #2:
#   protocol: 6
#   local_port: 0
#   remote_port: 0
#   remote_ip: 0.0.0.2
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [rip = 3, proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 3}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [0 == lport, 0 == rport, 3 == rip]
# 6
# local_port
# [6 == proto, 0 == rport, 3 == rip]
# 0
# remote_port
# [6 == proto, 0 == lport, 3 == rip]
# 0
# remote_ip
# [6 == proto, 0 == lport, 0 == rport]
# 3
# {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 3}
# Generalized Counterexample #3:
#   protocol: 6
#   local_port: 0
#   remote_port: 0
#   remote_ip: 0.0.0.3
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [rip = 4, proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 4}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [0 == lport, 0 == rport, 4 == rip]
# 6
# local_port
# [6 == proto, 0 == rport, 4 == rip]
# 0
# remote_port
# [6 == proto, 0 == lport, 4 == rip]
# 0
# remote_ip
# [6 == proto, 0 == lport, 0 == rport]
# 4
# {'protocol': 6, 'local_port': 0, 'remote_port': 0, 'remote_ip': 4}
# Generalized Counterexample #4:
#   protocol: 6
#   local_port: 0
#   remote_port: 0
#   remote_ip: 0.0.0.4
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [lport = 5, proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 5, 'remote_port': 0, 'remote_ip': 0}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [5 == lport, 0 == rport, 0 == rip]
# 6
# local_port
# [6 == proto, 0 == rport, 0 == rip]
# 5
# remote_port
# [6 == proto, 5 == lport, 0 == rip]
# 0
# remote_ip
# [6 == proto, 5 == lport, 0 == rport]
# 0
# {'protocol': 6, 'local_port': 5, 'remote_port': 0, 'remote_ip': 0}
# Generalized Counterexample #5:
#   protocol: 6
#   local_port: 5
#   remote_port: 0
#   remote_ip: 0.0.0.0
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [rport = 7, proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 0, 'remote_port': 7, 'remote_ip': 0}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [0 == lport, 7 == rport, 0 == rip]
# 6
# local_port
# [6 == proto, 7 == rport, 0 == rip]
# 0
# remote_port
# [6 == proto, 0 == lport, 0 == rip]
# 7
# remote_ip
# [6 == proto, 0 == lport, 7 == rport]
# 0
# {'protocol': 6, 'local_port': 0, 'remote_port': 7, 'remote_ip': 0}
# Generalized Counterexample #6:
#   protocol: 6
#   local_port: 0
#   remote_port: 7
#   remote_ip: 0.0.0.0
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
# ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------
# [rip = 14, rport = 16, lport = 15, proto = 6]
# Concrete packet from model: {'protocol': 6, 'local_port': 15, 'remote_port': 16, 'remote_ip': 14}
# {'protocol': proto, 'local_port': lport, 'remote_port': rport, 'remote_ip': rip}
# protocol
# [15 == lport, 16 == rport, 14 == rip]
# 6
# local_port
# [6 == proto, 16 == rport, 14 == rip]
# 15
# remote_port
# [6 == proto, 15 == lport, 14 == rip]
# 16
# remote_ip
# [6 == proto, 15 == lport, 16 == rport]
# 14
# {'protocol': 6, 'local_port': 15, 'remote_port': 16, 'remote_ip': 14}
# Generalized Counterexample #10:
#   protocol: 6
#   local_port: 15
#   remote_port: 16
#   remote_ip: 0.0.0.14
#   Firewall 1 allows? False (Matching rules: ['AnyDesk', 'AnyDesk', 'AnyDesk', 'AnyDesk', 'brave.exe', 'ChatGPT', 'Logi Options+ Agent', 'Logi Options+ Agent', 'Logi Plugin Service', 'Visual Studio Code', 'VLC media player', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', '@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', '@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', '@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', '@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', '@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', '@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST_VIDEO_APP_NAME}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22640.1000.0_x64__cw5n1h2txyewy?ms-resource://MicrosoftWindows.Client.CBS/resources/ProductPkgDisplayName}', '@{MicrosoftWindows.Client.CBS_1000.22700.1041.0_x64__cw5n1h2txyew ...
#   Firewall 2 allows? True (Matching rules: ['@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', '@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', '@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', '@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', '@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', '@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', '@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', '@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', '@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', '@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', '@{Microsoft.Windows.C ...
# --------------------------------------------------

# %% [markdown]
# ## FINAL

# %%
import ipaddress
import csv
from z3 import *
from typing import List, Dict, Generator, Optional

# Represents an IP address range from 'low' to 'high'
class AddressRange:
    def __init__(self, low: str, high: str):
        self.low = ipaddress.IPv4Address(low)
        self.high = ipaddress.IPv4Address(high)

# Represents a set of address ranges or a wildcard for all addresses
class AddressSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[AddressRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

# Represents a port range from 'low' to 'high'
class PortRange:
    def __init__(self, low: int, high: int):
        self.low = low
        self.high = high

# Represents a set of port ranges or a wildcard for all ports
class PortSet:
    def __init__(self, contains_all: bool = False, ranges: Optional[List[PortRange]] = None):
        self.contains_all = contains_all
        self.ranges = ranges or []

# Represents a network protocol (e.g., TCP, UDP, ICMP)
class NetworkProtocol:
    def __init__(self, any_protocol: bool = False, protocol_number: int = 0):
        self.any = any_protocol
        self.protocol_number = protocol_number

    @staticmethod
    def try_get_protocol_number(name: str) -> Optional[int]:
        """Map protocol name to number"""
        protocol_map = {
            "HOPOPT": 0,
            "ICMP": 1,
            "IGMP": 2,
            "TCP": 6,
            "UDP": 17,
            "IPv6": 41,
            "IPv6-Route": 43,
            "IPv6-Frag": 44,
            "GRE": 47,
            "ICMPv6": 58,
            "IPv6-NoNxt": 59,
            "IPv6-Opts": 60,
            "VRRP": 112,
            "PGM": 113,
            "L2TP": 115
        }
        return protocol_map.get(name.upper())

# Represents a single firewall rule
class WindowsFirewallRule:
    def __init__(self, name: str, remote_addresses: AddressSet, remote_ports: PortSet,
                 local_ports: PortSet, protocol: NetworkProtocol, enabled: bool, allow: bool):
        self.name = name
        self.remote_addresses = remote_addresses
        self.remote_ports = remote_ports
        self.local_ports = local_ports
        self.protocol = protocol
        self.enabled = enabled
        self.allow = allow

    def __str__(self):
        """Provides a human-readable string representation of the rule"""
        return (
            f"Rule: {self.name}\n"
            f"  Enabled: {self.enabled}, Action: {'Allow' if self.allow else 'Block'}\n"
            f"  Protocol: {'Any' if self.protocol.any else self.protocol.protocol_number}\n"
            f"  Local Ports: {'Any' if self.local_ports.contains_all else [(r.low, r.high) for r in self.local_ports.ranges]}\n"
            f"  Remote Ports: {'Any' if self.remote_ports.contains_all else [(r.low, r.high) for r in self.remote_ports.ranges]}\n"
            f"  Remote Addresses: {'Any' if self.remote_addresses.contains_all else [(str(r.low), str(r.high)) for r in self.remote_addresses.ranges]}"
        )

# Parses firewall rules from a CSV or TSV file
class WindowsFirewallRuleParser:
    REQUIRED_HEADERS = [
        "Name", "Enabled", "Action", "Local Port",
        "Remote Address", "Remote Port", "Protocol"
    ]

    @staticmethod
    def parse(text: str, separator: str) -> Generator[WindowsFirewallRule, None, None]:
        """
        Parses the given CSV/TSV text into firewall rules
        """
        reader = csv.reader(text.strip().splitlines(), delimiter=separator)
        header_line = next(reader)
        header_index = WindowsFirewallRuleParser.parse_header(header_line)

        for i, line in enumerate(reader):
            try:
                yield WindowsFirewallRuleParser.parse_record(header_index, line)
            except Exception as e:
                print(f"Skipping line {i + 2} - {e}")

    @staticmethod
    def parse_header(header_line: List[str]) -> Dict[str, int]:
        """Builds a mapping from header names to their index positions"""
        header_index = {h.strip(): i for i, h in enumerate(header_line)}
        missing = [h for h in WindowsFirewallRuleParser.REQUIRED_HEADERS if h not in header_index]
        if missing:
            raise ValueError(f"Missing required headers: {', '.join(missing)}")
        return header_index

    @staticmethod
    def parse_record(header_index: Dict[str, int], record: List[str]) -> WindowsFirewallRule:
        """Parses a single row of the firewall rules CSV into a rule object"""
        def get(field: str) -> str:
            return record[header_index[field]].strip()

        return WindowsFirewallRule(
            name=get("Name"),
            remote_addresses=WindowsFirewallRuleParser.parse_address_set(get("Remote Address")),
            remote_ports=WindowsFirewallRuleParser.parse_port_set(get("Remote Port")),
            local_ports=WindowsFirewallRuleParser.parse_port_set(get("Local Port")),
            protocol=WindowsFirewallRuleParser.parse_network_protocol(get("Protocol")),
            enabled=(get("Enabled") == "Yes"),
            allow=(get("Action") == "Allow")
        )

    @staticmethod
    def parse_address_set(text: str) -> AddressSet:
        """Parses a string representing an address set into an AddressSet object"""
        if text == "Any":
            return AddressSet(contains_all=True)

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(AddressRange(low.strip(), high.strip()))
            else:
                ranges.append(AddressRange(part, part))
        return AddressSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_port_set(text: str) -> PortSet:
        """Parses a string representing a port set into a PortSet object"""
        if not text:
            raise ValueError("Port is empty")

        if text == "Any":
            return PortSet(contains_all=True)

        unsupported_macros = {
            "RPC Endpoint Mapper", "RPC Dynamic Ports",
            "IPHTTPS", "Edge Traversal", "PlayTo Discovery"
        }
        if text in unsupported_macros:
            raise ValueError(f"Unsupported port macro: {text}")

        ranges = []
        for part in text.split(','):
            part = part.strip()
            if '-' in part:
                low, high = part.split('-')
                ranges.append(PortRange(int(low.strip()), int(high.strip())))
            else:
                val = int(part)
                ranges.append(PortRange(val, val))
        return PortSet(contains_all=False, ranges=ranges)

    @staticmethod
    def parse_network_protocol(text: str) -> NetworkProtocol:
        """Parses the protocol field into a NetworkProtocol object"""
        if text == "Any":
            return NetworkProtocol(any_protocol=True)

        protocol_number = NetworkProtocol.try_get_protocol_number(text)
        if protocol_number is None:
            protocol_number = int(text)

        return NetworkProtocol(any_protocol=False, protocol_number=protocol_number)

class FirewallEquivalenceChecker:
    def __init__(self, rules1, rules2, block_by_default=True):
        self.rules1 = rules1
        self.rules2 = rules2
        self.block_by_default = block_by_default

    def allows(self, rules, packet):
        block_exprs = []
        allow_exprs = []

        for rule in rules:
            if not rule.enabled:
                continue

            proto_cond = BoolVal(True) if rule.protocol.any else packet['protocol'] == rule.protocol.protocol_number
            local_port_cond = self.port_set_expr(packet['local_port'], rule.local_ports)
            remote_port_cond = self.port_set_expr(packet['remote_port'], rule.remote_ports)
            remote_addr_cond = self.address_set_expr(packet['remote_ip'], rule.remote_addresses)

            match_expr = And(proto_cond, local_port_cond, remote_port_cond, remote_addr_cond)

            if rule.allow:
                allow_exprs.append(match_expr)
            else:
                block_exprs.append(match_expr)

        has_block = Or(*block_exprs) if block_exprs else BoolVal(False)
        has_allow = Or(*allow_exprs) if allow_exprs else BoolVal(False)

        if not self.block_by_default:
            return Not(has_block)
        else:
            return And(has_allow, Not(has_block))

    def port_set_expr(self, port_var, port_set):
        if port_set.contains_all:
            return BoolVal(True)
        return Or([And(port_var >= r.low, port_var <= r.high) for r in port_set.ranges])

    def address_set_expr(self, ip_var, addr_set):
        if addr_set.contains_all:
            return BoolVal(True)
        return Or([
            And(ip_var >= self.ip_to_int(r.low), ip_var <= self.ip_to_int(r.high))
            for r in addr_set.ranges
        ])

    def ip_to_int(self, ip):
        return int(ip)

    def packet_from_model(self, model, packet_vars):
        """
        Extract packet values from model.
        If variable is undefined, replace with "Any".
        """
        packet_values = {}
        packet_values_constraint = {}
        for k, v in packet_vars.items():
            if model[v] is not None :
                val = model.eval(v, model_completion=True)
                if k == 'remote_ip':
                    try:
                        packet_values_constraint[k] = val
                        packet_values[k] = str(ipaddress.IPv4Address(val.as_long()))
                    except Exception:
                        packet_values[k] = "Any"
                else:
                    packet_values_constraint[k] = val
                    packet_values[k] = val.as_long() if hasattr(val, 'as_long') else val
            else :
                packet_values[k] = "Any"
        return packet_values, packet_values_constraint

    def rules_matching_packet(self, rules, packet_values):
        """
        Returns list of rule names that match the concrete packet.
        'packet_values' is a dict with concrete values (or 'Any')
        """
        matched_rules = []
        for rule in rules:
            if not rule.enabled:
                continue

            if not self.rule_matches_packet(rule, packet_values):
                continue

            action = "Allow" if rule.allow else "Block"
            matched_rules.append((rule.name if hasattr(rule, 'name') else "UnnamedRule", action))
        return matched_rules

    def rule_matches_packet(self, rule, packet_values):
        """
        Check if a rule matches a concrete packet (values, not symbolic)
        Supports 'Any' meaning unconstrained.
        """
        def port_in_set(port, port_set):
            if port == "Any":
                return True
            for r in port_set.ranges:
                if r.low <= port <= r.high:
                    return True
            return port_set.contains_all

        def addr_in_set(ip_str, addr_set):
            if ip_str == "Any":
                return True
            ip_int = int(ipaddress.IPv4Address(ip_str))
            for r in addr_set.ranges:
                low_int = int(r.low)
                high_int = int(r.high)
                if low_int <= ip_int <= high_int:
                    return True
            return addr_set.contains_all

        # Protocol match
        if not rule.protocol.any:
            if packet_values['protocol'] != "Any" and packet_values['protocol'] != rule.protocol.protocol_number:
                return False

        # Ports
        if not port_in_set(packet_values['local_port'], rule.local_ports):
            return False
        if not port_in_set(packet_values['remote_port'], rule.remote_ports):
            return False

        # Addresses
        if not addr_in_set(packet_values['remote_ip'], rule.remote_addresses):
            return False

        return True
    

    def check_equivalence(self, max_counterexamples=10):
        s = Solver()
        packet = {
            'protocol': Int('proto'),
            'local_port': Int('lport'),
            'remote_port': Int('rport'),
            'remote_ip': Int('rip')
        }

        f1_allows = self.allows(self.rules1, packet)
        f2_allows = self.allows(self.rules2, packet)

        s.add(f1_allows != f2_allows)

        found = 0
        print("-" * 50)
        if s.check() == sat:
            print("\n❌ Firewalls are NOT equivalent.\n")
            print("-" * 50)
            
        while found < max_counterexamples and s.check() == sat:
            m = s.model()
            pkt_vals, pkt_vals_const = self.packet_from_model(m, packet)

            f1_allowed = is_true(m.eval(f1_allows, model_completion=True))
            f2_allowed = is_true(m.eval(f2_allows, model_completion=True))


            f1_matching_rules = self.rules_matching_packet(self.rules1, pkt_vals)
            f2_matching_rules = self.rules_matching_packet(self.rules2, pkt_vals)

            print(f"Counterexample #{found+1}:")
            for k, v in pkt_vals.items():
                if k == 'protocol':
                    reversed_protocol_map = {0: "HOPOPT", 1: "ICMP", 2: "IGMP", 6: "TCP", 17: "UDP", 41: "IPv6", 43: "IPv6-Route", 44: "IPv6-Frag", 47: "GRE", 58: "ICMPv6", 59: "IPv6-NoNxt", 60: "IPv6-Opts", 112: "VRRP", 113: "PGM", 115: "L2TP"}
                    v = reversed_protocol_map.get(v, v)  

                print(f"  {k}: {v}")

            print(f"  Firewall 1 allows? {f1_allowed} (Matching rules: {f1_matching_rules})")
            print(f"  Firewall 2 allows? {f2_allowed} (Matching rules: {f2_matching_rules})")
            print("-" * 50)

            # Block this solution for next iteration
            block_current = []
            for k,v in pkt_vals_const.items():
                block_current.append(packet[k] != v)
            s.add(Or(block_current))

            found += 1

        if found == 0:
            print("✅ Firewalls are equivalent.")

if __name__ == '__main__':

    sep = '\t'  
    file1 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1.txt'
    file2 = 'D:\Documents\GitHub\FirewallChecker\sharanya_1_out.txt'

    with open(file1) as f1:
        rules1 = list(WindowsFirewallRuleParser.parse(f1.read(), sep))
    with open(file2) as f2:
        rules2 = list(WindowsFirewallRuleParser.parse(f2.read(), sep))
    checker = FirewallEquivalenceChecker(rules1, rules2)
    checker.check_equivalence()
# Out:
# Skipping line 69 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 70 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 71 - Unsupported port macro: PlayTo Discovery
# Skipping line 72 - Expected 4 octets in 'Local subnet'
# Skipping line 74 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 76 - Expected 4 octets in 'Local subnet'
# Skipping line 77 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'Local subnet'
# Skipping line 81 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 86 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 87 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 91 - Unsupported port macro: IPHTTPS
# Skipping line 92 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 93 - Expected 4 octets in 'Local subnet'
# Skipping line 94 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Expected 4 octets in 'Local subnet'
# Skipping line 96 - Expected 4 octets in 'Local subnet'
# Skipping line 97 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 98 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 99 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 100 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 101 - Unexpected '/' in 'fe80::/64'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - Unsupported port macro: Edge Traversal
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 107 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 108 - Expected 4 octets in 'Local subnet'
# Skipping line 113 - Expected 4 octets in 'Local subnet'
# Skipping line 114 - Expected 4 octets in 'Local subnet'
# Skipping line 115 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 117 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 118 - Expected 4 octets in 'Local subnet'
# Skipping line 121 - Expected 4 octets in 'Local subnet'
# Skipping line 122 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 123 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 126 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 134 - Expected 4 octets in 'Local subnet'
# Skipping line 135 - Expected 4 octets in 'Local subnet'
# Skipping line 136 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 139 - Expected 4 octets in 'Local subnet'
# Skipping line 140 - Expected 4 octets in 'Local subnet'
# Skipping line 141 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 142 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 143 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 144 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 145 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 146 - Expected 4 octets in 'Local subnet'
# Skipping line 147 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 151 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 152 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 153 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 154 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 155 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 164 - Expected 4 octets in 'Local subnet'
# Skipping line 165 - Expected 4 octets in 'Local subnet'
# Skipping line 166 - Expected 4 octets in 'Local subnet'
# Skipping line 167 - Expected 4 octets in 'Local subnet'
# Skipping line 168 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 170 - Expected 4 octets in 'Local subnet'
# Skipping line 171 - Expected 4 octets in 'Local subnet'
# Skipping line 172 - Expected 4 octets in 'Local subnet'
# Skipping line 177 - Expected 4 octets in 'Local subnet'
# Skipping line 178 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 187 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 190 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 202 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 207 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 212 - Expected 4 octets in 'Local subnet'
# Skipping line 213 - Expected 4 octets in 'Local subnet'
# Skipping line 214 - Expected 4 octets in 'Local subnet'
# Skipping line 217 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 226 - Expected 4 octets in 'Local subnet'
# Skipping line 227 - Expected 4 octets in 'Local subnet'
# Skipping line 231 - Expected 4 octets in 'Local subnet'
# Skipping line 232 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 233 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 235 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 236 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 237 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 238 - Expected 4 octets in 'Local subnet'
# Skipping line 239 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 240 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 241 - Expected 4 octets in 'Local subnet'
# Skipping line 242 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 245 - Expected 4 octets in 'Local subnet'
# Skipping line 246 - Expected 4 octets in 'Local subnet'
# Skipping line 247 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 248 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 249 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 250 - Expected 4 octets in 'Local subnet'
# Skipping line 251 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 252 - Expected 4 octets in 'Local subnet'
# Skipping line 253 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 254 - Expected 4 octets in 'Local subnet'
# Skipping line 255 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 266 - Expected 4 octets in 'Local subnet'
# Skipping line 268 - Expected 4 octets in 'Local subnet'
# Skipping line 270 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 271 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 273 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 281 - Expected 4 octets in 'Local subnet'
# Skipping line 282 - Unsupported port macro: RPC Dynamic Ports
# Skipping line 283 - Expected 4 octets in 'Local subnet'
# Skipping line 284 - Unsupported port macro: RPC Endpoint Mapper
# Skipping line 285 - Expected 4 octets in 'Local subnet'
# Skipping line 290 - Expected 4 octets in 'Local subnet'
# Skipping line 291 - Expected 4 octets in 'Local subnet'
# Skipping line 293 - Expected 4 octets in 'Local subnet'
# Skipping line 297 - Expected 4 octets in 'Local subnet'
# Skipping line 299 - Expected 4 octets in 'Local subnet'
# Skipping line 301 - Expected 4 octets in 'Local subnet'
# Skipping line 303 - Expected 4 octets in 'Local subnet'
# Skipping line 307 - Expected 4 octets in 'Local subnet'
# Skipping line 308 - Expected 4 octets in 'Local subnet'
# Skipping line 309 - Expected 4 octets in 'Local subnet'
# Skipping line 78 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 79 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 80 - Expected 4 octets in 'PlayTo Renderers'
# Skipping line 82 - Expected 4 octets in 'Local subnet'
# Skipping line 95 - Unsupported port macro: IPHTTPS
# Skipping line 96 - invalid literal for int() with base 10: 'IPv6'
# Skipping line 97 - Expected 4 octets in 'Local subnet'
# Skipping line 98 - Expected 4 octets in 'Local subnet'
# Skipping line 99 - Expected 4 octets in 'Local subnet'
# Skipping line 100 - Expected 4 octets in 'Local subnet'
# Skipping line 101 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 102 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 103 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 104 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 105 - Expected 4 octets in 'Local subnet'
# Skipping line 106 - Expected 4 octets in 'Local subnet'
# Skipping line 108 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 109 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 110 - Expected 4 octets in 'Local subnet'
# Skipping line 111 - Expected 4 octets in 'Local subnet'
# Skipping line 112 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 116 - Expected 4 octets in 'Local subnet'
# Skipping line 119 - Expected 4 octets in 'Local subnet'
# Skipping line 120 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 121 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 122 - Expected 4 octets in 'Local subnet'
# Skipping line 123 - Expected 4 octets in 'Local subnet'
# Skipping line 124 - Expected 4 octets in 'Local subnet'
# Skipping line 125 - Expected 4 octets in 'Local subnet'
# Skipping line 127 - Expected 4 octets in 'Local subnet'
# Skipping line 130 - Expected 4 octets in 'Local subnet'
# Skipping line 131 - Expected 4 octets in 'Local subnet'
# Skipping line 133 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 134 - invalid literal for int() with base 10: 'ICMPv4'
# Skipping line 135 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 136 - invalid literal for int() with base 10: 'ICMPv6'
# Skipping line 137 - Expected 4 octets in 'Local subnet'
# Skipping line 138 - Expected 4 octets in 'Local subnet'
# Skipping line 148 - Expected 4 octets in 'Local subnet'
# Skipping line 150 - Expected 4 octets in 'Local subnet'
# Skipping line 152 - Expected 4 octets in 'Local subnet'
# Skipping line 155 - Expected 4 octets in 'Local subnet'
# Skipping line 156 - Expected 4 octets in 'Local subnet'
# Skipping line 157 - Expected 4 octets in 'Local subnet'
# Skipping line 158 - Expected 4 octets in 'Local subnet'
# Skipping line 159 - Expected 4 octets in 'Local subnet'
# Skipping line 160 - Expected 4 octets in 'Local subnet'
# Skipping line 161 - Expected 4 octets in 'Local subnet'
# Skipping line 162 - Expected 4 octets in 'Local subnet'
# Skipping line 163 - Expected 4 octets in 'Local subnet'
# Skipping line 169 - Expected 4 octets in 'Local subnet'
# Skipping line 182 - Expected 4 octets in 'Local subnet'
# Skipping line 183 - Expected 4 octets in 'Local subnet'
# Skipping line 184 - Expected 4 octets in 'Local subnet'
# Skipping line 185 - Expected 4 octets in 'Local subnet'
# Skipping line 186 - Expected 4 octets in 'Local subnet'
# Skipping line 188 - Expected 4 octets in 'Local subnet'
# Skipping line 189 - Expected 4 octets in 'Local subnet'
# Skipping line 191 - Expected 4 octets in 'Local subnet'
# Skipping line 192 - Expected 4 octets in 'Local subnet'
# Skipping line 193 - Expected 4 octets in 'Local subnet'
# Skipping line 194 - Expected 4 octets in 'Local subnet'
# Skipping line 195 - Expected 4 octets in 'Local subnet'
# Skipping line 196 - Expected 4 octets in 'Local subnet'
# Skipping line 197 - Expected 4 octets in 'Local subnet'
# Skipping line 198 - Expected 4 octets in 'Local subnet'
# Skipping line 199 - Expected 4 octets in 'Local subnet'
# Skipping line 200 - Expected 4 octets in 'Local subnet'
# Skipping line 201 - Expected 4 octets in 'Local subnet'
# Skipping line 204 - Expected 4 octets in 'Local subnet'
# Skipping line 205 - Expected 4 octets in 'Local subnet'
# Skipping line 206 - Expected 4 octets in 'Local subnet'
# Skipping line 208 - Expected 4 octets in 'Local subnet'
# Skipping line 209 - Expected 4 octets in 'Local subnet'
# Skipping line 210 - Expected 4 octets in 'Local subnet'
# Skipping line 211 - Expected 4 octets in 'Local subnet'
# Skipping line 220 - Expected 4 octets in 'Local subnet'
# Skipping line 221 - Expected 4 octets in 'Local subnet'
# Skipping line 234 - Expected 4 octets in 'Local subnet'
# Skipping line 244 - Expected 4 octets in 'Local subnet'
# Skipping line 258 - Expected 4 octets in 'Local subnet'
# Skipping line 262 - Expected 4 octets in 'Local subnet'
# Skipping line 264 - Expected 4 octets in 'Local subnet'
# Skipping line 275 - Expected 4 octets in 'Local subnet'
# Skipping line 277 - Expected 4 octets in 'Local subnet'
# Skipping line 278 - Expected 4 octets in 'Local subnet'
# Skipping line 279 - Expected 4 octets in 'Local subnet'
# Skipping line 280 - Expected 4 octets in 'Local subnet'
# --------------------------------------------------
#
# ❌ Firewalls are NOT equivalent.
#
# --------------------------------------------------
# Counterexample #1:
#   protocol: TCP
#   local_port: Any
#   remote_port: Any
#   remote_ip: Any
#   Firewall 1 allows? False (Matching rules: [('AnyDesk', 'Allow'), ('AnyDesk', 'Allow'), ('AnyDesk', 'Allow'), ('AnyDesk', 'Allow'), ('brave.exe', 'Block'), ('ChatGPT', 'Allow'), ('Logi Options+ Agent', 'Allow'), ('Logi Options+ Agent', 'Allow'), ('Logi Plugin Service', 'Allow'), ('Port 3306', 'Allow'), ('Port 33060', 'Allow'), ('Visual Studio Code', 'Allow'), ('VLC media player', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', 'Allow'), ('@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', 'Allow'), ('@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', 'Allow'), ('@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', 'Allow'), ('@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', 'Allow'), ('@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', 'Allow'), ('@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-reso ...
#   Firewall 2 allows? True (Matching rules: [('@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', 'Allow'), ('@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', 'Allow'), ('@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', 'Allow'), ('@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', 'Allow'), ('@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', 'Allow'), ('@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', 'Allow'), ('@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', 'Allow'), ('@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', 'Allow'), ('@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', 'Allow'), ('@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', 'Allow'), ('@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', 'Allow'), ('@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10. ...
# --------------------------------------------------
# Counterexample #2:
#   protocol: UDP
#   local_port: Any
#   remote_port: Any
#   remote_ip: Any
#   Firewall 1 allows? False (Matching rules: [('AnyDesk', 'Allow'), ('AnyDesk', 'Allow'), ('AnyDesk', 'Allow'), ('AnyDesk', 'Allow'), ('brave.exe', 'Block'), ('ChatGPT', 'Allow'), ('Logi Options+ Agent', 'Allow'), ('Logi Options+ Agent', 'Allow'), ('Logi Plugin Service', 'Allow'), ('Visual Studio Code', 'Allow'), ('VLC media player', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', 'Allow'), ('@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.2506_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.Photos_21.21030.25003.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Windows.Photos/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', 'Allow'), ('@{Microsoft.Windows.StartMenuExperienceHost_10.0.22621.4249_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.StartMenuExperienceHost/StartMenuExperienceHost/PkgDisplayName}', 'Allow'), ('@{microsoft.windowscommunicationsapps_16005.14326.20544.0_x64__8wekyb3d8bbwe?ms-resource://microsoft.windowscommunicationsapps/hxoutlookintl/AppManifest_OutlookDesktop_DisplayName}', 'Allow'), ('@{Microsoft.WindowsFeedbackHub_1.2411.17101.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsFeedbackHub/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.WindowsMixedRealityRuntimeApp_113.2403.5001.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.WindowsMixedRealityRuntimeApp/Resources/displayName}', 'Allow'), ('@{Microsoft.XboxGamingOverlay_2.622.3232.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.XboxGamingOverlay/resources/GameBar}', 'Allow'), ('@{Microsoft.ZuneMusic_11.2202.46.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneMusic/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.ZuneVideo_10.22020.10021.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.ZuneVideo/resources/IDS_MANIFEST ...
#   Firewall 2 allows? True (Matching rules: [('@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', 'Allow'), ('@{EnvironmentsApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://EnvironmentsApp/resources/DisplayName}', 'Allow'), ('@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', 'Allow'), ('@{HoloItemPlayerApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloItemPlayerApp/resources/DisplayName}', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{HoloShell_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://HoloShell/resources/DisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AAD.BrokerPlugin_1000.19580.1000.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.AAD.BrokerPlugin/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', 'Allow'), ('@{Microsoft.AccountsControl_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.AccountsControl/Resources/DisplayName}', 'Allow'), ('@{Microsoft.DesktopAppInstaller_1.17.10691.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.DesktopAppInstaller/Resources/appDisplayName}', 'Allow'), ('@{Microsoft.GetHelp_10.2201.421.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.GetHelp/Resources/appDisplayName}', 'Allow'), ('@{Microsoft.Getstarted_10.2204.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Getstarted/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.LockApp_10.0.22621.1_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', 'Allow'), ('@{Microsoft.LockApp_10.0.22621.3235_neutral__cw5n1h2txyewy?ms-resource://Microsoft.LockApp/resources/AppDisplayName}', 'Allow'), ('@{Microsoft.Microsoft3DViewer_7.2401.29012.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Microsoft3DViewer/Common.View.UWP/Resources/StoreAppName}', 'Allow'), ('@{Microsoft.People_10.1909.12456.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.People/Resources/AppStoreName}', 'Allow'), ('@{Microsoft.PPIProjection_10.0.26100.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.PPIProjection/resources/ProductNameWindowsStore}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.SecHealthUI_1000.22621.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.SecHealthUI/resources/PackageDisplayName}', 'Allow'), ('@{Microsoft.StorePurchaseApp_12008.1001.1.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.StorePurchaseApp/Resources/DisplayTitle}', 'Allow'), ('@{Microsoft.Todos_0.54.42772.0_x64__8wekyb3d8bbwe?ms-resource://Microsoft.Todos/Resources/app_name_ms_todo}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Win32WebViewHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Windows.Win32WebViewHost/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.Apprep.ChxApp_1000.22621.1.0_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.Apprep.ChxApp/resources/DisplayName}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10.0.22621.1_neutral_neutral_cw5n1h2txyewy?ms-resource://Microsoft.Windows.CloudExperienceHost/resources/appDescription}', 'Allow'), ('@{Microsoft.Windows.CloudExperienceHost_10. ...
# --------------------------------------------------
